# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, LeakyReLU
from tensorflow.keras.activations import relu, sigmoid, tanh  
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from keras.initializers import HeNormal


import AC_Import_CG_AE_Test as chase_ae_cg_tune
import AD_Import_FG_AE_Tune as chase_ae_fg_tune
# Out:
# 2024-05-10 13:42:06.777152: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-10 13:42:06.777190: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-10 13:42:06.778602: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-10 13:42:06.906253: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-10 13:42:08.277336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Import and Prep

# %%
# Load and concatenate dataframes
wt_f = chase_ae_cg_tune.load_and_concatenate('wt', 'wt')
D132H_f = chase_ae_cg_tune.load_and_concatenate('D132H', 'D132H')
D132H_f.index = range(40000, 40000 + len(D132H_f))

# Preprocessing
X_train_f, X_valid_f, y_train_f, y_valid_f = chase_ae_cg_tune.preprocessing_alt(wt_f, D132H_f)
# Out:
# (64000, 153)
# (16000, 153)
# (64000, 1)
# (16000, 1)

# %% [markdown]
# # Autoencoder Models
# 1. 3 layers (672: ReLU, 672, LeReLU:672, LeReLU:672) LR: 5E-5, BS: 765
# 2. 6 layers (608: LeReLU, 640:ReLU, 608: ReLU, 256:TanH, 192:ReLU, 480:Sigmoid) LR:1.96048E-5, BS:765
# 3. 5 layers (672: ReLU, 64: LeReLU, 640: TanH, 480: LeReLU, 128: ReLU) LR:3.07378E-5, BS:459
# 4. 6 layers (672: LeReLU, 672: ReLU, 576: ReLU, 32: LeReLU, 352: ReLU, 608: ReLU) LR:1E-5, BS:765
# 5. 6 layers (672: LeReLU, 672: ReLU, 672: ReLU, 32: LeReLU, 32: ReLU, 672: TanH) LR:1E-5, BS:765
# 6. 5 layers (256: LeReLU, 128: ReLU, 416: ReLU, 256: ReLU, 32:LeReLU) LR:1.22209E-5, BS:765
# 7. 4 layers (672: LeReLU, 32: LeReLU, 672: LeReLU, 672: LeReLU) LR:1E-5, BS:612
# 8. 6 layers (672: ReLU, 32: LeReLU, 672: LeReLU, 352: LeReLU, 32: ReLU, 32: LeReLU) LR:1E-5, BS:153
# 9. 6 layers (672: LeReLU, 672: ReLU, 352: ReLU, 32: LeReLU, 32: ReLU, 224: TanH) LR:1E-5, BS:765

# %% [markdown]
# # Trial Analysis:

# %% [markdown]
# ### Random Seed 1

# %%
# Define the base directory where the models' training histories are stored
base_directory = "AE_Testing_RS_1"

# Epochs of interest for comparison
epochs_of_interest = [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]

# Function to load training history and extract validation loss at specified epochs
def get_validation_losses(model_id):
    model_folder = os.path.join(base_directory, f"Model_{model_id}")
    history_path = os.path.join(model_folder, 'Training_History.csv')
    
    # Check if the history file exists
    if os.path.exists(history_path):
        history_data = pd.read_csv(history_path)
        
        # Extract validation losses at the epochs of interest
        validation_losses = {}
        for epoch in epochs_of_interest:
            if epoch - 1 < len(history_data):
                validation_losses[epoch] = history_data.loc[epoch - 1, 'val_loss']
            else:
                validation_losses[epoch] = None
        return validation_losses
    else:
        print(f"No history data found for Model_{model_id}")
        return None

# Load validation losses for all models and rank them
rankings = []
for model_id in range(1, 10):  
    val_losses = get_validation_losses(model_id)
    if val_losses:
        rankings.append((model_id, val_losses))

# Sort and print rankings for each specified epoch
for epoch in epochs_of_interest:
    print(f"Random Seed Ranking at Epoch {epoch}:")
    sorted_rankings = sorted(rankings, key=lambda x: x[1][epoch] if x[1][epoch] is not None else float('inf'))
    for rank, (model_id, losses) in enumerate(sorted_rankings, 1):
        loss_value = losses[epoch]
        if loss_value is not None:
            print(f"  Rank {rank}: Model {model_id} with Validation Loss: {loss_value}")
        else:
            print(f"  Rank {rank}: Model {model_id} - No Data Available")
    print("\n")
# Out:
# Random Seed Ranking at Epoch 200:
#   Rank 1: Model 4 with Validation Loss: 0.0009515552665106
#   Rank 2: Model 2 with Validation Loss: 0.0009639551280997
#   Rank 3: Model 9 with Validation Loss: 0.0009740320965647
#   Rank 4: Model 5 with Validation Loss: 0.000990278320387
#   Rank 5: Model 1 with Validation Loss: 0.0009984056232497
#   Rank 6: Model 3 with Validation Loss: 0.0010074815945699
#   Rank 7: Model 7 with Validation Loss: 0.0010449995752424
#   Rank 8: Model 8 with Validation Loss: 0.0010664011351764
#   Rank 9: Model 6 with Validation Loss: 0.0010801778407767
#
#
# Random Seed Ranking at Epoch 400:
#   Rank 1: Model 4 with Validation Loss: 0.0008682572515681
#   Rank 2: Model 9 with Validation Loss: 0.0009103764896281
#   Rank 3: Model 1 with Validation Loss: 0.0009271960007026
#   Rank 4: Model 2 with Validation Loss: 0.0009314069175161
#   Rank 5: Model 3 with Validation Loss: 0.0009323523845523
#   Rank 6: Model 5 with Validation Loss: 0.0009427060140296
#   Rank 7: Model 7 with Validation Loss: 0.000975529605057
#   Rank 8: Model 6 with Validation Loss: 0.0009915193077176
#   Rank 9: Model 8 with Validation Loss: 0.0009920630836859
#
#
# Random Seed Ranking at Epoch 600:
#   Rank 1: Model 4 with Validation Loss: 0.0008452798356302
#   Rank 2: Model 2 with Validation Loss: 0.0008657484431751
#   Rank 3: Model 5 with Validation Loss: 0.0008671976393088
#   Rank 4: Model 9 with Validation Loss: 0.0008757447940297
#   Rank 5: Model 3 with Validation Loss: 0.0008906503790058
#   Rank 6: Model 1 with Validation Loss: 0.0008986763423308
#   Rank 7: Model 7 with Validation Loss: 0.0009393276413902
#   Rank 8: Model 8 with Validation Loss: 0.0009427774348296
#   Rank 9: Model 6 with Validation Loss: 0.0009523828630335
#
#
# Random Seed Ranking at Epoch 800:
#   Rank 1: Model 4 with Validation Loss: 0.0008052844787016
#   Rank 2: Model 5 with Validation Loss: 0.0008452230249531
#   Rank 3: Model 9 with Validation Loss: 0.0008586594485677
#   Rank 4: Model 3 with Validation Loss: 0.0008662050240673
#   Rank 5: Model 2 with Validation Loss: 0.0008748729014769
#   Rank 6: Model 1 with Validation Loss: 0.0008863537805154
#   Rank 7: Model 7 with Validation Loss: 0.0008999784477055
#   Rank 8: Model 8 with Validation Loss: 0.0009188416879624
#   Rank 9: Model 6 with Validation Loss: 0.0009196872706525
#
#
# Random Seed Ranking at Epoch 1000:
#   Rank 1: Model 4 with Validation Loss: 0.0007894381997175
#   Rank 2: Model 5 with Validation Loss: 0.0008278526947833
#   Rank 3: Model 2 with Validation Loss: 0.0008440632955171
#   Rank 4: Model 3 with Validation Loss: 0.0008469399763271
#   Rank 5: Model 9 with Validation Loss: 0.0008629693184047
#   Rank 6: Model 1 with Validation Loss: 0.0008721371414139
#   Rank 7: Model 7 with Validation Loss: 0.0008857503999024
#   Rank 8: Model 8 with Validation Loss: 0.0008989613852463
#   Rank 9: Model 6 with Validation Loss: 0.0009065459598787
#
#
# Random Seed Ranking at Epoch 1200:
#   Rank 1: Model 4 with Validation Loss: 0.000769940437749
#   Rank 2: Model 5 with Validation Loss: 0.0008044017595238
#   Rank 3: Model 2 with Validation Loss: 0.0008133599185384
#   Rank 4: Model 3 with Validation Loss: 0.0008278311579488
#   Rank 5: Model 9 with Validation Loss: 0.0008409257279708
#   Rank 6: Model 7 with Validation Loss: 0.0008656577556394
#   Rank 7: Model 1 with Validation Loss: 0.0008701714687049
#   Rank 8: Model 8 with Validation Loss: 0.0008758674957789
#   Rank 9: Model 6 with Validation Loss: 0.000895072997082
#
#
# Random Seed Ranking at Epoch 1400:
#   Rank 1: Model 4 with Validation Loss: 0.0007604213897138
#   Rank 2: Model 2 with Validation Loss: 0.0008082141866907
#   Rank 3: Model 5 with Validation Loss: 0.000820352055598
#   Rank 4: Model 3 with Validation Loss: 0.0008226106292568
#   Rank 5: Model 9 with Validation Loss: 0.0008321040077134
#   Rank 6: Model 7 with Validation Loss: 0.000845827627927
#   Rank 7: Model 8 with Validation Loss: 0.0008641825988888
#   Rank 8: Model 1 with Validation Loss: 0.0008685487555339
#   Rank 9: Model 6 with Validation Loss: 0.0008846491691656
#
#
# Random Seed Ranking at Epoch 1600:
#   Rank 1: Model 4 with Validation Loss: 0.0007459134794771
#   Rank 2: Model 5 with Validation Loss: 0.0007779070874676
#   Rank 3: Model 2 with Validation Loss: 0.0007876509916968
#   Rank 4: Model 3 with Validation Loss: 0.000808238517493
#   Rank 5: Model 9 with Validation Loss: 0.0008235847926698
#   Rank 6: Model 7 with Validation Loss: 0.0008414923795498
#   Rank 7: Model 8 with Validation Loss: 0.0008498958777636
#   Rank 8: Model 1 with Validation Loss: 0.0008617035928182
#   Rank 9: Model 6 with Validation Loss: 0.0008668591617606
#
#
# Random Seed Ranking at Epoch 1800:
#   Rank 1: Model 4 with Validation Loss: 0.0007278377888724
#   Rank 2: Model 2 with Validation Loss: 0.0007731819059699
#   Rank 3: Model 5 with Validation Loss: 0.0007948637357912
#   Rank 4: Model 3 with Validation Loss: 0.0008090750779956
#   Rank 5: Model 9 with Validation Loss: 0.0008189812651835
#   Rank 6: Model 7 with Validation Loss: 0.0008339289342984
#   Rank 7: Model 8 with Validation Loss: 0.0008506652666255
#   Rank 8: Model 1 with Validation Loss: 0.000864018627908
#   Rank 9: Model 6 with Validation Loss: 0.0008655638666823
#
#
# Random Seed Ranking at Epoch 2000:
#   Rank 1: Model 4 with Validation Loss: 0.0007165421848185
#   Rank 2: Model 2 with Validation Loss: 0.0007711253128945
#   Rank 3: Model 5 with Validation Loss: 0.0007728326600044
#   Rank 4: Model 3 with Validation Loss: 0.0007991843158379
#   Rank 5: Model 9 with Validation Loss: 0.0008212246466428
#   Rank 6: Model 7 with Validation Loss: 0.000834985577967
#   Rank 7: Model 8 with Validation Loss: 0.0008375165634788
#   Rank 8: Model 6 with Validation Loss: 0.0008504522847943
#   Rank 9: Model 1 with Validation Loss: 0.0008648326038382

# %%
# Define the base directory where the models' training histories are stored
base_directory = "AE_Testing_RS_1"

# Epochs of interest for comparison
epochs_of_interest = [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]

# Function to load training history and extract validation loss at specified epochs
def get_losses(model_id):
    model_folder = os.path.join(base_directory, f"Model_{model_id}")
    history_path = os.path.join(model_folder, 'Training_History.csv')
    
    # Check if the history file exists
    if os.path.exists(history_path):
        history_data = pd.read_csv(history_path)
        
        # Extract validation losses at the epochs of interest
        losses = {}
        for epoch in epochs_of_interest:
            if epoch - 1 < len(history_data):
                losses[epoch] = history_data.loc[epoch - 1, 'loss']
            else:
                losses[epoch] = None
        return losses
    else:
        print(f"No history data found for Model_{model_id}")
        return None

# Load validation losses for all models and rank them
rankings = []
for model_id in range(1, 10):  
    losses = get_losses(model_id)
    if losses:
        rankings.append((model_id, losses))

# Sort and print rankings for each specified epoch
for epoch in epochs_of_interest:
    print(f"Random Seed Ranking at Epoch {epoch}:")
    sorted_rankings = sorted(rankings, key=lambda x: x[1][epoch] if x[1][epoch] is not None else float('inf'))
    for rank, (model_id, losses) in enumerate(sorted_rankings, 1):
        loss_value = losses[epoch]
        if loss_value is not None:
            print(f"  Rank {rank}: Model {model_id} with Loss: {loss_value}")
        else:
            print(f"  Rank {rank}: Model {model_id} - No Data Available")
    print("\n")
# Out:
# Random Seed Ranking at Epoch 200:
#   Rank 1: Model 4 with Loss: 0.0009231267031282
#   Rank 2: Model 9 with Loss: 0.0009415397653356
#   Rank 3: Model 2 with Loss: 0.0009472523233853
#   Rank 4: Model 5 with Loss: 0.0009682255913503
#   Rank 5: Model 1 with Loss: 0.0009788372553884
#   Rank 6: Model 3 with Loss: 0.0009950962848961
#   Rank 7: Model 7 with Loss: 0.0010329589713364
#   Rank 8: Model 6 with Loss: 0.0010580122470855
#   Rank 9: Model 8 with Loss: 0.0010600409004837
#
#
# Random Seed Ranking at Epoch 400:
#   Rank 1: Model 4 with Loss: 0.0008337060571648
#   Rank 2: Model 9 with Loss: 0.0008517408859916
#   Rank 3: Model 1 with Loss: 0.000896344485227
#   Rank 4: Model 2 with Loss: 0.0009131194092333
#   Rank 5: Model 3 with Loss: 0.0009193171863444
#   Rank 6: Model 5 with Loss: 0.0009473410318605
#   Rank 7: Model 7 with Loss: 0.0009581284830346
#   Rank 8: Model 6 with Loss: 0.0009661793010309
#   Rank 9: Model 8 with Loss: 0.0009707977878861
#
#
# Random Seed Ranking at Epoch 600:
#   Rank 1: Model 4 with Loss: 0.000795382016804
#   Rank 2: Model 9 with Loss: 0.0008010925375856
#   Rank 3: Model 5 with Loss: 0.0008347373805008
#   Rank 4: Model 1 with Loss: 0.0008458667434751
#   Rank 5: Model 2 with Loss: 0.0008519747061654
#   Rank 6: Model 3 with Loss: 0.0008781654178164
#   Rank 7: Model 7 with Loss: 0.0009124487405642
#   Rank 8: Model 6 with Loss: 0.0009134045685641
#   Rank 9: Model 8 with Loss: 0.0009272621246054
#
#
# Random Seed Ranking at Epoch 800:
#   Rank 1: Model 4 with Loss: 0.000757775385864
#   Rank 2: Model 9 with Loss: 0.0007706101750954
#   Rank 3: Model 5 with Loss: 0.0008058332605287
#   Rank 4: Model 1 with Loss: 0.0008124512969516
#   Rank 5: Model 2 with Loss: 0.0008453210466541
#   Rank 6: Model 3 with Loss: 0.00084835360758
#   Rank 7: Model 7 with Loss: 0.0008800554205663
#   Rank 8: Model 6 with Loss: 0.000881424639374
#   Rank 9: Model 8 with Loss: 0.000895163975656
#
#
# Random Seed Ranking at Epoch 1000:
#   Rank 1: Model 4 with Loss: 0.0007471426506526
#   Rank 2: Model 9 with Loss: 0.0007534615579061
#   Rank 3: Model 5 with Loss: 0.0007816979195922
#   Rank 4: Model 1 with Loss: 0.0007899547927081
#   Rank 5: Model 2 with Loss: 0.0008048697491176
#   Rank 6: Model 3 with Loss: 0.0008293424616567
#   Rank 7: Model 6 with Loss: 0.0008573032100684
#   Rank 8: Model 7 with Loss: 0.0008575256215408
#   Rank 9: Model 8 with Loss: 0.0008740405319258
#
#
# Random Seed Ranking at Epoch 1200:
#   Rank 1: Model 9 with Loss: 0.0007230929331853
#   Rank 2: Model 4 with Loss: 0.0007260683923959
#   Rank 3: Model 5 with Loss: 0.0007445432129316
#   Rank 4: Model 1 with Loss: 0.0007692163926549
#   Rank 5: Model 2 with Loss: 0.0007781644235365
#   Rank 6: Model 3 with Loss: 0.0008136694086715
#   Rank 7: Model 6 with Loss: 0.0008397381170652
#   Rank 8: Model 7 with Loss: 0.0008419497753493
#   Rank 9: Model 8 with Loss: 0.0008582744630984
#
#
# Random Seed Ranking at Epoch 1400:
#   Rank 1: Model 4 with Loss: 0.000705684768036
#   Rank 2: Model 9 with Loss: 0.0007064469973556
#   Rank 3: Model 1 with Loss: 0.0007543484098277
#   Rank 4: Model 2 with Loss: 0.0007572359172627
#   Rank 5: Model 5 with Loss: 0.0007608989835716
#   Rank 6: Model 3 with Loss: 0.0007975727785378
#   Rank 7: Model 6 with Loss: 0.0008249056991189
#   Rank 8: Model 7 with Loss: 0.0008268753299489
#   Rank 9: Model 8 with Loss: 0.0008422813843935
#
#
# Random Seed Ranking at Epoch 1600:
#   Rank 1: Model 9 with Loss: 0.0006969476235099
#   Rank 2: Model 4 with Loss: 0.000702898192685
#   Rank 3: Model 5 with Loss: 0.0007121363887563
#   Rank 4: Model 2 with Loss: 0.0007261546561494
#   Rank 5: Model 1 with Loss: 0.0007407790981233
#   Rank 6: Model 3 with Loss: 0.0007907344261184
#   Rank 7: Model 7 with Loss: 0.0008105636807158
#   Rank 8: Model 6 with Loss: 0.0008123705629259
#   Rank 9: Model 8 with Loss: 0.0008314913138747
#
#
# Random Seed Ranking at Epoch 1800:
#   Rank 1: Model 4 with Loss: 0.0006828138721175
#   Rank 2: Model 9 with Loss: 0.0006851690122857
#   Rank 3: Model 5 with Loss: 0.0007079794886521
#   Rank 4: Model 2 with Loss: 0.000708119419869
#   Rank 5: Model 1 with Loss: 0.0007260012789629
#   Rank 6: Model 3 with Loss: 0.0007843937491998
#   Rank 7: Model 6 with Loss: 0.0007977728382684
#   Rank 8: Model 7 with Loss: 0.00080102449283
#   Rank 9: Model 8 with Loss: 0.0008180798031389
#
#
# Random Seed Ranking at Epoch 2000:
#   Rank 1: Model 4 with Loss: 0.0006777177914045
#   Rank 2: Model 9 with Loss: 0.0006782793207094
#   Rank 3: Model 5 with Loss: 0.0006902806344442
#   Rank 4: Model 2 with Loss: 0.0007117206114344
#   Rank 5: Model 1 with Loss: 0.0007164221606217
#   Rank 6: Model 3 with Loss: 0.0007785797934047
#   Rank 7: Model 7 with Loss: 0.0007857952150516
#   Rank 8: Model 6 with Loss: 0.0007897064788267
#   Rank 9: Model 8 with Loss: 0.0008119025733321

# %% [markdown]
# #### He Weight Initialization

# %%
# Define the base directory where the models' training histories are stored
base_directory = "AE_Testing_RS_He"

# Epochs of interest for comparison
epochs_of_interest = [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]

# Function to load training history and extract validation loss at specified epochs
def get_validation_losses(model_id):
    model_folder = os.path.join(base_directory, f"Model_{model_id}")
    history_path = os.path.join(model_folder, 'Training_History.csv')
    
    # Check if the history file exists
    if os.path.exists(history_path):
        history_data = pd.read_csv(history_path)
        
        # Extract validation losses at the epochs of interest
        validation_losses = {}
        for epoch in epochs_of_interest:
            if epoch - 1 < len(history_data):
                validation_losses[epoch] = history_data.loc[epoch - 1, 'val_loss']
            else:
                validation_losses[epoch] = None  # In case the history does not reach the specified epoch
        return validation_losses
    else:
        print(f"No history data found for Model_{model_id}")
        return None

# Load validation losses for all models and rank them
rankings = []
for model_id in range(1, 10):  # Assuming model IDs are 1 through 9
    val_losses = get_validation_losses(model_id)
    if val_losses:
        rankings.append((model_id, val_losses))

# Sort and print rankings for each specified epoch
for epoch in epochs_of_interest:
    print(f"He Weight Initialization Ranking at Epoch {epoch}:")
    sorted_rankings = sorted(rankings, key=lambda x: x[1][epoch] if x[1][epoch] is not None else float('inf'))
    for rank, (model_id, losses) in enumerate(sorted_rankings, 1):
        loss_value = losses[epoch]
        if loss_value is not None:
            print(f"  Rank {rank}: Model {model_id} with Validation Loss: {loss_value}")
        else:
            print(f"  Rank {rank}: Model {model_id} - No Data Available")
    print("\n")
# Out:
# He Weight Initialization Ranking at Epoch 200:
#   Rank 1: Model 4 with Validation Loss: 0.0009397438261657
#   Rank 2: Model 2 with Validation Loss: 0.0009763558628037
#   Rank 3: Model 5 with Validation Loss: 0.0010077318875119
#   Rank 4: Model 3 with Validation Loss: 0.0010276496177539
#   Rank 5: Model 9 with Validation Loss: 0.0010441904887557
#   Rank 6: Model 8 with Validation Loss: 0.001055012922734
#   Rank 7: Model 1 with Validation Loss: 0.00106415245682
#   Rank 8: Model 7 with Validation Loss: 0.0010659013641998
#   Rank 9: Model 6 with Validation Loss: 0.0010865200310945
#
#
# He Weight Initialization Ranking at Epoch 400:
#   Rank 1: Model 4 with Validation Loss: 0.0008798991912044
#   Rank 2: Model 2 with Validation Loss: 0.00094357249327
#   Rank 3: Model 3 with Validation Loss: 0.0009581069462001
#   Rank 4: Model 5 with Validation Loss: 0.0009632827714085
#   Rank 5: Model 8 with Validation Loss: 0.0009969380917027
#   Rank 6: Model 7 with Validation Loss: 0.0010129819856956
#   Rank 7: Model 6 with Validation Loss: 0.0010224394500255
#   Rank 8: Model 1 with Validation Loss: 0.0010403837077319
#   Rank 9: Model 9 with Validation Loss: 0.0010677853133529
#
#
# He Weight Initialization Ranking at Epoch 600:
#   Rank 1: Model 4 with Validation Loss: 0.0008412848692387
#   Rank 2: Model 3 with Validation Loss: 0.0009217138285748
#   Rank 3: Model 2 with Validation Loss: 0.0009289310546591
#   Rank 4: Model 5 with Validation Loss: 0.0009389394544996
#   Rank 5: Model 8 with Validation Loss: 0.0009458316490054
#   Rank 6: Model 7 with Validation Loss: 0.0009603151702322
#   Rank 7: Model 9 with Validation Loss: 0.0009647281840443
#   Rank 8: Model 6 with Validation Loss: 0.000995727488771
#   Rank 9: Model 1 with Validation Loss: 0.0010235381778329
#
#
# He Weight Initialization Ranking at Epoch 800:
#   Rank 1: Model 4 with Validation Loss: 0.0008192585664801
#   Rank 2: Model 3 with Validation Loss: 0.0008941887062974
#   Rank 3: Model 2 with Validation Loss: 0.0009213511948473
#   Rank 4: Model 8 with Validation Loss: 0.0009244671091437
#   Rank 5: Model 9 with Validation Loss: 0.0009331210167147
#   Rank 6: Model 5 with Validation Loss: 0.0009359437972307
#   Rank 7: Model 7 with Validation Loss: 0.0009446799522265
#   Rank 8: Model 6 with Validation Loss: 0.0009807061869651
#   Rank 9: Model 1 with Validation Loss: 0.0010221959091722
#
#
# He Weight Initialization Ranking at Epoch 1000:
#   Rank 1: Model 4 with Validation Loss: 0.0007902643410488
#   Rank 2: Model 3 with Validation Loss: 0.0008840745431371
#   Rank 3: Model 2 with Validation Loss: 0.0009214626043103
#   Rank 4: Model 7 with Validation Loss: 0.0009258025093004
#   Rank 5: Model 5 with Validation Loss: 0.0009341410477645
#   Rank 6: Model 9 with Validation Loss: 0.0009553563431836
#   Rank 7: Model 6 with Validation Loss: 0.0009609914268366
#   Rank 8: Model 8 with Validation Loss: 0.0009650635183788
#   Rank 9: Model 1 with Validation Loss: 0.0010233358480036
#
#
# He Weight Initialization Ranking at Epoch 1200:
#   Rank 1: Model 4 with Validation Loss: 0.0007929224520921
#   Rank 2: Model 3 with Validation Loss: 0.000874915102031
#   Rank 3: Model 8 with Validation Loss: 0.0008859717636369
#   Rank 4: Model 7 with Validation Loss: 0.0009104026830755
#   Rank 5: Model 2 with Validation Loss: 0.0009147960226982
#   Rank 6: Model 5 with Validation Loss: 0.0009368780301883
#   Rank 7: Model 6 with Validation Loss: 0.0009416614193469
#   Rank 8: Model 9 with Validation Loss: 0.0009647535625845
#   Rank 9: Model 1 with Validation Loss: 0.0010239731054753
#
#
# He Weight Initialization Ranking at Epoch 1400:
#   Rank 1: Model 4 with Validation Loss: 0.0007628236780874
#   Rank 2: Model 3 with Validation Loss: 0.0008474175701849
#   Rank 3: Model 8 with Validation Loss: 0.0009032433154061
#   Rank 4: Model 7 with Validation Loss: 0.0009105227072723
#   Rank 5: Model 2 with Validation Loss: 0.0009227304835803
#   Rank 6: Model 6 with Validation Loss: 0.0009377468959428
#   Rank 7: Model 5 with Validation Loss: 0.0009445661562494
#   Rank 8: Model 9 with Validation Loss: 0.0009896826231852
#   Rank 9: Model 1 with Validation Loss: 0.0010272536892443
#
#
# He Weight Initialization Ranking at Epoch 1600:
#   Rank 1: Model 4 with Validation Loss: 0.000758881738875
#   Rank 2: Model 3 with Validation Loss: 0.0008520609117113
#   Rank 3: Model 8 with Validation Loss: 0.0008678651647642
#   Rank 4: Model 7 with Validation Loss: 0.0008843424730002
#   Rank 5: Model 2 with Validation Loss: 0.0009260516380891
#   Rank 6: Model 9 with Validation Loss: 0.0009341207914985
#   Rank 7: Model 6 with Validation Loss: 0.0009355252841487
#   Rank 8: Model 5 with Validation Loss: 0.0009403164149262
#   Rank 9: Model 1 with Validation Loss: 0.0010310092475265
#
#
# He Weight Initialization Ranking at Epoch 1800:
#   Rank 1: Model 4 with Validation Loss: 0.0007549551082774
#   Rank 2: Model 3 with Validation Loss: 0.0008389399154111
#   Rank 3: Model 8 with Validation Loss: 0.0008534223306924
#   Rank 4: Model 9 with Validation Loss: 0.0008920051623135
#   Rank 5: Model 7 with Validation Loss: 0.0009065988706424
#   Rank 6: Model 6 with Validation Loss: 0.0009263249812647
#   Rank 7: Model 2 with Validation Loss: 0.0009318655938841
#   Rank 8: Model 5 with Validation Loss: 0.0009449200588278
#   Rank 9: Model 1 with Validation Loss: 0.0010324594331905
#
#
# He Weight Initialization Ranking at Epoch 2000:
#   Rank 1: Model 4 with Validation Loss: 0.0007703722221776
#   Rank 2: Model 3 with Validation Loss: 0.0008172418456524
#   Rank 3: Model 8 with Validation Loss: 0.0008532942738384
#   Rank 4: Model 7 with Validation Loss: 0.000878740043845
#   Rank 5: Model 9 with Validation Loss: 0.0008814702159725
#   Rank 6: Model 6 with Validation Loss: 0.0009147434029728
#   Rank 7: Model 2 with Validation Loss: 0.0009312782203778
#   Rank 8: Model 5 with Validation Loss: 0.0009497808059677
#   Rank 9: Model 1 with Validation Loss: 0.0010345355840399

# %%
# Define the base directory where the models' training histories are stored
base_directory = "AE_Testing_RS_He"

# Epochs of interest for comparison
epochs_of_interest = [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]

# Function to load training history and extract validation loss at specified epochs
def get_losses(model_id):
    model_folder = os.path.join(base_directory, f"Model_{model_id}")
    history_path = os.path.join(model_folder, 'Training_History.csv')
    
    # Check if the history file exists
    if os.path.exists(history_path):
        history_data = pd.read_csv(history_path)
        
        # Extract validation losses at the epochs of interest
        losses = {}
        for epoch in epochs_of_interest:
            if epoch - 1 < len(history_data):
                losses[epoch] = history_data.loc[epoch - 1, 'loss']
            else:
                losses[epoch] = None
        return losses
    else:
        print(f"No history data found for Model_{model_id}")
        return None

# Load validation losses for all models and rank them
rankings = []
for model_id in range(1, 10):  
    losses = get_losses(model_id)
    if losses:
        rankings.append((model_id, losses))

# Sort and print rankings for each specified epoch
for epoch in epochs_of_interest:
    print(f"He Weight Initialization Ranking at Epoch {epoch}:")
    sorted_rankings = sorted(rankings, key=lambda x: x[1][epoch] if x[1][epoch] is not None else float('inf'))
    for rank, (model_id, losses) in enumerate(sorted_rankings, 1):
        loss_value = losses[epoch]
        if loss_value is not None:
            print(f"  Rank {rank}: Model {model_id} with Loss: {loss_value}")
        else:
            print(f"  Rank {rank}: Model {model_id} - No Data Available")
    print("\n")
# Out:
# He Weight Initialization Ranking at Epoch 200:
#   Rank 1: Model 2 with Loss: 0.0008984691812656
#   Rank 2: Model 4 with Loss: 0.0009245949331671
#   Rank 3: Model 5 with Loss: 0.0009739966480992
#   Rank 4: Model 1 with Loss: 0.0009793866192921
#   Rank 5: Model 3 with Loss: 0.0010151712922379
#   Rank 6: Model 9 with Loss: 0.0010275864042341
#   Rank 7: Model 8 with Loss: 0.001036527683027
#   Rank 8: Model 7 with Loss: 0.0010586376301944
#   Rank 9: Model 6 with Loss: 0.0010794787667691
#
#
# He Weight Initialization Ranking at Epoch 400:
#   Rank 1: Model 4 with Loss: 0.0008342639775946
#   Rank 2: Model 2 with Loss: 0.0008412000024691
#   Rank 3: Model 5 with Loss: 0.0008857836364768
#   Rank 4: Model 1 with Loss: 0.0009265818516723
#   Rank 5: Model 3 with Loss: 0.0009342361008748
#   Rank 6: Model 8 with Loss: 0.000967348634731
#   Rank 7: Model 7 with Loss: 0.0009723188122734
#   Rank 8: Model 6 with Loss: 0.0010002328781411
#   Rank 9: Model 9 with Loss: 0.0010336514096707
#
#
# He Weight Initialization Ranking at Epoch 600:
#   Rank 1: Model 4 with Loss: 0.0007824780768714
#   Rank 2: Model 2 with Loss: 0.0007958129281178
#   Rank 3: Model 5 with Loss: 0.0008335022139362
#   Rank 4: Model 1 with Loss: 0.0008884582202881
#   Rank 5: Model 3 with Loss: 0.0008966570603661
#   Rank 6: Model 7 with Loss: 0.0009242140804417
#   Rank 7: Model 8 with Loss: 0.0009280553204007
#   Rank 8: Model 6 with Loss: 0.0009563414496369
#   Rank 9: Model 9 with Loss: 0.0009575159638188
#
#
# He Weight Initialization Ranking at Epoch 800:
#   Rank 1: Model 2 with Loss: 0.0007617035880684
#   Rank 2: Model 4 with Loss: 0.0007623947458341
#   Rank 3: Model 5 with Loss: 0.0007965596741996
#   Rank 4: Model 1 with Loss: 0.0008577473927289
#   Rank 5: Model 3 with Loss: 0.000864383240696
#   Rank 6: Model 7 with Loss: 0.0008938513929024
#   Rank 7: Model 8 with Loss: 0.0009114166605286
#   Rank 8: Model 6 with Loss: 0.0009236293844878
#   Rank 9: Model 9 with Loss: 0.0009434263920411
#
#
# He Weight Initialization Ranking at Epoch 1000:
#   Rank 1: Model 4 with Loss: 0.0007238348480314
#   Rank 2: Model 2 with Loss: 0.0007343273609876
#   Rank 3: Model 5 with Loss: 0.0007676046225242
#   Rank 4: Model 1 with Loss: 0.0008311971905641
#   Rank 5: Model 3 with Loss: 0.0008488794555887
#   Rank 6: Model 7 with Loss: 0.0008682350162416
#   Rank 7: Model 8 with Loss: 0.0008860825910232
#   Rank 8: Model 6 with Loss: 0.00089778075926
#   Rank 9: Model 9 with Loss: 0.0009512591641396
#
#
# He Weight Initialization Ranking at Epoch 1200:
#   Rank 1: Model 2 with Loss: 0.0007111122831702
#   Rank 2: Model 4 with Loss: 0.0007206175359897
#   Rank 3: Model 5 with Loss: 0.0007439279579557
#   Rank 4: Model 1 with Loss: 0.0008099953993223
#   Rank 5: Model 3 with Loss: 0.0008300017216242
#   Rank 6: Model 7 with Loss: 0.0008502242853865
#   Rank 7: Model 8 with Loss: 0.0008715455187484
#   Rank 8: Model 6 with Loss: 0.0008766733808442
#   Rank 9: Model 9 with Loss: 0.0009369977633468
#
#
# He Weight Initialization Ranking at Epoch 1400:
#   Rank 1: Model 2 with Loss: 0.0006890907534398
#   Rank 2: Model 4 with Loss: 0.0006975110154598
#   Rank 3: Model 5 with Loss: 0.0007223031716421
#   Rank 4: Model 1 with Loss: 0.0007942031370475
#   Rank 5: Model 3 with Loss: 0.0008315343875437
#   Rank 6: Model 7 with Loss: 0.000835099897813
#   Rank 7: Model 6 with Loss: 0.0008636204292997
#   Rank 8: Model 8 with Loss: 0.0008709728717803
#   Rank 9: Model 9 with Loss: 0.0009452390950173
#
#
# He Weight Initialization Ranking at Epoch 1600:
#   Rank 1: Model 2 with Loss: 0.0006708254804834
#   Rank 2: Model 4 with Loss: 0.0006896802224218
#   Rank 3: Model 5 with Loss: 0.0007042343495413
#   Rank 4: Model 1 with Loss: 0.0007757553248666
#   Rank 5: Model 3 with Loss: 0.0008089249604381
#   Rank 6: Model 7 with Loss: 0.0008259915048256
#   Rank 7: Model 6 with Loss: 0.0008473645430058
#   Rank 8: Model 8 with Loss: 0.0008543334552086
#   Rank 9: Model 9 with Loss: 0.0008822251111268
#
#
# He Weight Initialization Ranking at Epoch 1800:
#   Rank 1: Model 2 with Loss: 0.0006541424663737
#   Rank 2: Model 4 with Loss: 0.0006776951486244
#   Rank 3: Model 5 with Loss: 0.0006895061815157
#   Rank 4: Model 1 with Loss: 0.000763455289416
#   Rank 5: Model 7 with Loss: 0.0008120338316075
#   Rank 6: Model 3 with Loss: 0.0008155948598869
#   Rank 7: Model 9 with Loss: 0.0008181646117009
#   Rank 8: Model 8 with Loss: 0.0008300996851176
#   Rank 9: Model 6 with Loss: 0.0008383721578866
#
#
# He Weight Initialization Ranking at Epoch 2000:
#   Rank 1: Model 2 with Loss: 0.0006387881585396
#   Rank 2: Model 5 with Loss: 0.0006747638108208
#   Rank 3: Model 4 with Loss: 0.0006888132775202
#   Rank 4: Model 1 with Loss: 0.000750390056055
#   Rank 5: Model 9 with Loss: 0.0007838630699552
#   Rank 6: Model 3 with Loss: 0.000784465984907
#   Rank 7: Model 7 with Loss: 0.0008043930865824
#   Rank 8: Model 6 with Loss: 0.0008248661761172
#   Rank 9: Model 8 with Loss: 0.0008297847234643

# %% [markdown]
# ## Model Analysis:

# %%
# Base directory paths
base_path_rs_1 = 'AE_Testing_RS_1'
base_path_rs_he = 'AE_Testing_RS_He'

# Color mappings for plotting
colors_rs_1 = ('darkred', 'lightcoral')  # loss, val_loss
colors_rs_he = ('darkblue', 'lightblue')  # loss, val_loss

# Number of models
num_models = 9

# Epoch limit
epoch_limit = 2000

# Create a directory to save plots
output_dir = 'AE_Testing_Overlaid_Plots_0_2000'
os.makedirs(output_dir, exist_ok=True)

# Function to read CSV and return training history data
def get_training_data(file_path):
    df = pd.read_csv(file_path)
    return df.iloc[:epoch_limit]['loss'], df.iloc[:epoch_limit]['val_loss']

# Plotting for each model
for model_num in range(1, num_models + 1):
    model_folder_name = f'Model_{model_num}'
    file_rs_1 = os.path.join(base_path_rs_1, model_folder_name, 'Training_History.csv')
    file_rs_he = os.path.join(base_path_rs_he, model_folder_name, 'Training_History.csv')
    
    # Fetch data for each file
    loss_rs_1, val_loss_rs_1 = get_training_data(file_rs_1)
    loss_rs_he, val_loss_rs_he = get_training_data(file_rs_he)

    # Plot data
    plt.figure(figsize=(10, 6))
    epochs = range(len(loss_rs_1))
    plt.plot(epochs, loss_rs_1, label='RS 1 Loss', color=colors_rs_1[0])
    plt.plot(epochs, val_loss_rs_1, label='RS 1 Val Loss', color=colors_rs_1[1])
    plt.plot(epochs, loss_rs_he, label='He Loss', color=colors_rs_he[0])
    plt.plot(epochs, val_loss_rs_he, label='He Val Loss', color=colors_rs_he[1])

    # Adding plot details
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Loss & Validation Loss Comparison for {model_folder_name}')
    plt.legend()
    plt.grid(True)

    # Save the plot to the output directory
    plt.savefig(os.path.join(output_dir, f'Loss_Comparison_{model_folder_name}.png'))
    plt.close()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Base directory paths
base_path_rs_1 = 'AE_Testing_RS_1'
base_path_rs_he = 'AE_Testing_RS_He'

# Color mappings for plotting
colors_rs_1 = ('darkred', 'lightcoral')  # loss, val_loss
colors_rs_he = ('darkblue', 'lightblue')  # loss, val_loss

# Number of models
num_models = 9

# Epoch range to plot
epoch_start = 50
epoch_limit = 2000

# Create a directory to save plots
output_dir = 'AE_Testing_Overlaid_Plots_51_2000'
os.makedirs(output_dir, exist_ok=True)

# Function to read CSV and return training history data
def get_training_data(file_path, start_epoch, max_epochs):
    df = pd.read_csv(file_path)
    # Ensure epochs beyond available data are not accessed
    end_epoch = min(max_epochs, len(df))
    return df.iloc[start_epoch:end_epoch]['loss'], df.iloc[start_epoch:end_epoch]['val_loss']

# Plotting for each model
for model_num in range(1, num_models + 1):
    model_folder_name = f'Model_{model_num}'
    file_rs_1 = os.path.join(base_path_rs_1, model_folder_name, 'Training_History.csv')
    file_rs_he = os.path.join(base_path_rs_he, model_folder_name, 'Training_History.csv')
    
    # Fetch data for each file starting from epoch 50
    loss_rs_1, val_loss_rs_1 = get_training_data(file_rs_1, epoch_start, epoch_limit)
    loss_rs_he, val_loss_rs_he = get_training_data(file_rs_he, epoch_start, epoch_limit)

    # Plot data
    plt.figure(figsize=(10, 6))
    epochs = range(epoch_start, epoch_start + len(loss_rs_1))
    plt.plot(epochs, loss_rs_1, label='RS 1 Loss', color=colors_rs_1[0])
    plt.plot(epochs, val_loss_rs_1, label='RS 1 Val Loss', color=colors_rs_1[1])
    plt.plot(epochs, loss_rs_he, label='He Loss', color=colors_rs_he[0])
    plt.plot(epochs, val_loss_rs_he, label='He Val Loss', color=colors_rs_he[1])

    # Adding plot details
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Loss Comparison for {model_folder_name} (Epochs {epoch_start}-{epoch_limit - 1})')
    plt.legend()
    plt.grid(True)

    # Save the plot to the output directory
    plt.savefig(os.path.join(output_dir, f'Loss_Comparison_{model_folder_name}.png'))
    plt.close()

# %%
# Base directory paths
base_path_rs_1 = 'AE_Testing_RS_1'
base_path_rs_he = 'AE_Testing_RS_He'

# Number of models
num_models = 9

# Function to read the entire CSV and return training history data
def get_training_data(file_path):
    return pd.read_csv(file_path)['loss'], pd.read_csv(file_path)['val_loss']

# Function to print minimum loss and validation loss values
def print_min_values(loss, val_loss, label_prefix):
    min_loss = loss.min()
    min_loss_epoch = loss.idxmin()
    min_val_loss = val_loss.min()
    min_val_loss_epoch = val_loss.idxmin()
    print(f"{label_prefix} Minimum Loss: {min_loss:.6f} at epoch {min_loss_epoch}")
    print(f"{label_prefix} Minimum Validation Loss: {min_val_loss:.6f} at epoch {min_val_loss_epoch}")

# Extract and print minimum values for each model
for model_num in range(1, num_models + 1):
    model_folder_name = f'Model_{model_num}'
    file_rs_1 = os.path.join(base_path_rs_1, model_folder_name, 'Training_History.csv')
    file_rs_he = os.path.join(base_path_rs_he, model_folder_name, 'Training_History.csv')
    
    # Fetch full data set for each file
    loss_rs_1, val_loss_rs_1 = get_training_data(file_rs_1)
    loss_rs_he, val_loss_rs_he = get_training_data(file_rs_he)

    # Print minimum values for both RS_1 and RS_He
    print(f"\nResults for {model_folder_name}:")
    print_min_values(loss_rs_1, val_loss_rs_1, "RS_1")
    print_min_values(loss_rs_he, val_loss_rs_he, "He_1")
# Out:
# Results for Model_1:
# RS_1 Minimum Loss: 0.000714 at epoch 1988
# RS_1 Minimum Validation Loss: 0.000859 at epoch 1833
# He_1 Minimum Loss: 0.000750 at epoch 1988
# He_1 Minimum Validation Loss: 0.001013 at epoch 887
#
# Results for Model_2:
# RS_1 Minimum Loss: 0.000690 at epoch 1971
# RS_1 Minimum Validation Loss: 0.000764 at epoch 1978
# He_1 Minimum Loss: 0.000638 at epoch 1995
# He_1 Minimum Validation Loss: 0.000914 at epoch 1002
#
# Results for Model_3:
# RS_1 Minimum Loss: 0.000768 at epoch 1957
# RS_1 Minimum Validation Loss: 0.000788 at epoch 1928
# He_1 Minimum Loss: 0.000780 at epoch 1970
# He_1 Minimum Validation Loss: 0.000813 at epoch 1980
#
# Results for Model_4:
# RS_1 Minimum Loss: 0.000671 at epoch 1948
# RS_1 Minimum Validation Loss: 0.000717 at epoch 1999
# He_1 Minimum Loss: 0.000666 at epoch 1991
# He_1 Minimum Validation Loss: 0.000743 at epoch 1995
#
# Results for Model_5:
# RS_1 Minimum Loss: 0.000681 at epoch 1974
# RS_1 Minimum Validation Loss: 0.000753 at epoch 1974
# He_1 Minimum Loss: 0.000675 at epoch 1999
# He_1 Minimum Validation Loss: 0.000931 at epoch 915
#
# Results for Model_6:
# RS_1 Minimum Loss: 0.000787 at epoch 1998
# RS_1 Minimum Validation Loss: 0.000846 at epoch 1983
# He_1 Minimum Loss: 0.000825 at epoch 1999
# He_1 Minimum Validation Loss: 0.000912 at epoch 1996
#
# Results for Model_7:
# RS_1 Minimum Loss: 0.000785 at epoch 1970
# RS_1 Minimum Validation Loss: 0.000812 at epoch 1995
# He_1 Minimum Loss: 0.000798 at epoch 1975
# He_1 Minimum Validation Loss: 0.000870 at epoch 1987
#
# Results for Model_8:
# RS_1 Minimum Loss: 0.000807 at epoch 1951
# RS_1 Minimum Validation Loss: 0.000827 at epoch 1989
# He_1 Minimum Loss: 0.000819 at epoch 1971
# He_1 Minimum Validation Loss: 0.000843 at epoch 1920
#
# Results for Model_9:
# RS_1 Minimum Loss: 0.000669 at epoch 1997
# RS_1 Minimum Validation Loss: 0.000811 at epoch 1977
# He_1 Minimum Loss: 0.000781 at epoch 1997
# He_1 Minimum Validation Loss: 0.000872 at epoch 1985

# %%
import os
import pandas as pd
import numpy as np

# Base directory paths
base_path_rs_1 = 'AE_Testing_RS_1'
base_path_rs_he = 'AE_Testing_RS_He'

# Number of models
num_models = 9

# Epoch ranges for median calculations
epoch_ranges = [(0, 199), (200, 399), (400, 599), (600, 799),
                (800, 999), (1000, 1199), (1200, 1399), (1400, 1599),
                (1600, 1799), (1800, 1999)]

# Function to read the entire CSV and return training history data
def get_training_data(file_path):
    return pd.read_csv(file_path)

# Function to print median loss and validation loss values
def print_median_values(df, range_start, range_end, label_prefix):
    range_df = df.iloc[range_start:range_end+1]
    median_loss = np.median(range_df['loss'])
    median_val_loss = np.median(range_df['val_loss'])

    # Find indices of the closest values to the median if exact match is not found
    median_loss_epoch = (np.abs(range_df['loss'] - median_loss)).idxmin()
    median_val_loss_epoch = (np.abs(range_df['val_loss'] - median_val_loss)).idxmin()

    print(f"{label_prefix} Range {range_start}-{range_end}: Median Loss {median_loss:.6f} at epoch {median_loss_epoch}, Median Validation Loss {median_val_loss:.6f} at epoch {median_val_loss_epoch}")

# Analyze and print values for each model and range
for model_num in range(1, num_models + 1):
    model_folder_name = f'Model_{model_num}'
    file_rs_1 = os.path.join(base_path_rs_1, model_folder_name, 'Training_History.csv')
    file_rs_he = os.path.join(base_path_rs_he, model_folder_name, 'Training_History.csv')
    
    # Fetch full data set for each file
    data_rs_1 = get_training_data(file_rs_1)
    data_rs_he = get_training_data(file_rs_he)

    # Print median values for both RS_1 and RS_He
    print(f"\nResults for {model_folder_name} (RS_1):")
    for start, end in epoch_ranges:
        print_median_values(data_rs_1, start, end, "RS_1")
    print(f"Results for {model_folder_name} (He_1):")
    for start, end in epoch_ranges:
        print_median_values(data_rs_he, start, end, "He_1")
# Out:
# Results for Model_1 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001060 at epoch 99, Median Validation Loss 0.001059 at epoch 99
# RS_1 Range 200-399: Median Loss 0.000932 at epoch 301, Median Validation Loss 0.000956 at epoch 296
# RS_1 Range 400-599: Median Loss 0.000868 at epoch 501, Median Validation Loss 0.000914 at epoch 493
# RS_1 Range 600-799: Median Loss 0.000828 at epoch 697, Median Validation Loss 0.000892 at epoch 739
# RS_1 Range 800-999: Median Loss 0.000800 at epoch 893, Median Validation Loss 0.000880 at epoch 900
# RS_1 Range 1000-1199: Median Loss 0.000779 at epoch 1098, Median Validation Loss 0.000872 at epoch 1132
# RS_1 Range 1200-1399: Median Loss 0.000762 at epoch 1287, Median Validation Loss 0.000868 at epoch 1221
# RS_1 Range 1400-1599: Median Loss 0.000746 at epoch 1489, Median Validation Loss 0.000865 at epoch 1463
# RS_1 Range 1600-1799: Median Loss 0.000733 at epoch 1704, Median Validation Loss 0.000864 at epoch 1733
# RS_1 Range 1800-1999: Median Loss 0.000720 at epoch 1897, Median Validation Loss 0.000864 at epoch 1871
# Results for Model_1 (He_1):
# He_1 Range 0-199: Median Loss 0.001013 at epoch 96, Median Validation Loss 0.001080 at epoch 126
# He_1 Range 200-399: Median Loss 0.000951 at epoch 297, Median Validation Loss 0.001043 at epoch 261
# He_1 Range 400-599: Median Loss 0.000907 at epoch 498, Median Validation Loss 0.001028 at epoch 453
# He_1 Range 600-799: Median Loss 0.000873 at epoch 700, Median Validation Loss 0.001021 at epoch 786
# He_1 Range 800-999: Median Loss 0.000844 at epoch 899, Median Validation Loss 0.001020 at epoch 953
# He_1 Range 1000-1199: Median Loss 0.000821 at epoch 1106, Median Validation Loss 0.001022 at epoch 1138
# He_1 Range 1200-1399: Median Loss 0.000801 at epoch 1303, Median Validation Loss 0.001024 at epoch 1248
# He_1 Range 1400-1599: Median Loss 0.000783 at epoch 1492, Median Validation Loss 0.001028 at epoch 1427
# He_1 Range 1600-1799: Median Loss 0.000769 at epoch 1692, Median Validation Loss 0.001032 at epoch 1779
# He_1 Range 1800-1999: Median Loss 0.000756 at epoch 1892, Median Validation Loss 0.001035 at epoch 1885
#
# Results for Model_2 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001045 at epoch 96, Median Validation Loss 0.001046 at epoch 91
# RS_1 Range 200-399: Median Loss 0.000950 at epoch 206, Median Validation Loss 0.000960 at epoch 354
# RS_1 Range 400-599: Median Loss 0.000878 at epoch 468, Median Validation Loss 0.000899 at epoch 505
# RS_1 Range 600-799: Median Loss 0.000843 at epoch 612, Median Validation Loss 0.000869 at epoch 624
# RS_1 Range 800-999: Median Loss 0.000818 at epoch 837, Median Validation Loss 0.000850 at epoch 904
# RS_1 Range 1000-1199: Median Loss 0.000792 at epoch 1071, Median Validation Loss 0.000834 at epoch 1105
# RS_1 Range 1200-1399: Median Loss 0.000762 at epoch 1257, Median Validation Loss 0.000813 at epoch 1296
# RS_1 Range 1400-1599: Median Loss 0.000742 at epoch 1412, Median Validation Loss 0.000798 at epoch 1588
# RS_1 Range 1600-1799: Median Loss 0.000724 at epoch 1695, Median Validation Loss 0.000786 at epoch 1619
# RS_1 Range 1800-1999: Median Loss 0.000707 at epoch 1956, Median Validation Loss 0.000777 at epoch 1963
# Results for Model_2 (He_1):
# He_1 Range 0-199: Median Loss 0.000932 at epoch 99, Median Validation Loss 0.000997 at epoch 105
# He_1 Range 200-399: Median Loss 0.000868 at epoch 300, Median Validation Loss 0.000958 at epoch 270
# He_1 Range 400-599: Median Loss 0.000816 at epoch 495, Median Validation Loss 0.000937 at epoch 509
# He_1 Range 600-799: Median Loss 0.000778 at epoch 697, Median Validation Loss 0.000927 at epoch 639
# He_1 Range 800-999: Median Loss 0.000748 at epoch 898, Median Validation Loss 0.000922 at epoch 909
# He_1 Range 1000-1199: Median Loss 0.000722 at epoch 1104, Median Validation Loss 0.000920 at epoch 1124
# He_1 Range 1200-1399: Median Loss 0.000700 at epoch 1300, Median Validation Loss 0.000920 at epoch 1349
# He_1 Range 1400-1599: Median Loss 0.000680 at epoch 1501, Median Validation Loss 0.000923 at epoch 1583
# He_1 Range 1600-1799: Median Loss 0.000662 at epoch 1700, Median Validation Loss 0.000927 at epoch 1691
# He_1 Range 1800-1999: Median Loss 0.000647 at epoch 1882, Median Validation Loss 0.000931 at epoch 1937
#
# Results for Model_3 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001076 at epoch 99, Median Validation Loss 0.001081 at epoch 99
# RS_1 Range 200-399: Median Loss 0.000949 at epoch 295, Median Validation Loss 0.000963 at epoch 311
# RS_1 Range 400-599: Median Loss 0.000896 at epoch 470, Median Validation Loss 0.000911 at epoch 458
# RS_1 Range 600-799: Median Loss 0.000863 at epoch 749, Median Validation Loss 0.000878 at epoch 660
# RS_1 Range 800-999: Median Loss 0.000842 at epoch 879, Median Validation Loss 0.000858 at epoch 976
# RS_1 Range 1000-1199: Median Loss 0.000828 at epoch 1063, Median Validation Loss 0.000845 at epoch 1096
# RS_1 Range 1200-1399: Median Loss 0.000811 at epoch 1306, Median Validation Loss 0.000830 at epoch 1222
# RS_1 Range 1400-1599: Median Loss 0.000801 at epoch 1453, Median Validation Loss 0.000820 at epoch 1447
# RS_1 Range 1600-1799: Median Loss 0.000795 at epoch 1664, Median Validation Loss 0.000813 at epoch 1640
# RS_1 Range 1800-1999: Median Loss 0.000782 at epoch 1848, Median Validation Loss 0.000802 at epoch 1811
# Results for Model_3 (He_1):
# He_1 Range 0-199: Median Loss 0.001092 at epoch 99, Median Validation Loss 0.001103 at epoch 99
# He_1 Range 200-399: Median Loss 0.000968 at epoch 296, Median Validation Loss 0.000992 at epoch 333
# He_1 Range 400-599: Median Loss 0.000914 at epoch 490, Median Validation Loss 0.000937 at epoch 467
# He_1 Range 600-799: Median Loss 0.000882 at epoch 675, Median Validation Loss 0.000909 at epoch 672
# He_1 Range 800-999: Median Loss 0.000859 at epoch 865, Median Validation Loss 0.000890 at epoch 903
# He_1 Range 1000-1199: Median Loss 0.000841 at epoch 1079, Median Validation Loss 0.000872 at epoch 1109
# He_1 Range 1200-1399: Median Loss 0.000829 at epoch 1212, Median Validation Loss 0.000861 at epoch 1268
# He_1 Range 1400-1599: Median Loss 0.000814 at epoch 1446, Median Validation Loss 0.000848 at epoch 1489
# He_1 Range 1600-1799: Median Loss 0.000805 at epoch 1651, Median Validation Loss 0.000841 at epoch 1613
# He_1 Range 1800-1999: Median Loss 0.000793 at epoch 1870, Median Validation Loss 0.000830 at epoch 1905
#
# Results for Model_4 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001015 at epoch 100, Median Validation Loss 0.001030 at epoch 97
# RS_1 Range 200-399: Median Loss 0.000866 at epoch 310, Median Validation Loss 0.000904 at epoch 287
# RS_1 Range 400-599: Median Loss 0.000807 at epoch 491, Median Validation Loss 0.000853 at epoch 487
# RS_1 Range 600-799: Median Loss 0.000777 at epoch 653, Median Validation Loss 0.000822 at epoch 647
# RS_1 Range 800-999: Median Loss 0.000752 at epoch 834, Median Validation Loss 0.000797 at epoch 902
# RS_1 Range 1000-1199: Median Loss 0.000734 at epoch 1053, Median Validation Loss 0.000779 at epoch 1028
# RS_1 Range 1200-1399: Median Loss 0.000718 at epoch 1384, Median Validation Loss 0.000763 at epoch 1367
# RS_1 Range 1400-1599: Median Loss 0.000705 at epoch 1594, Median Validation Loss 0.000749 at epoch 1483
# RS_1 Range 1600-1799: Median Loss 0.000697 at epoch 1650, Median Validation Loss 0.000743 at epoch 1655
# RS_1 Range 1800-1999: Median Loss 0.000689 at epoch 1806, Median Validation Loss 0.000733 at epoch 1802
# Results for Model_4 (He_1):
# He_1 Range 0-199: Median Loss 0.001013 at epoch 101, Median Validation Loss 0.001031 at epoch 94
# He_1 Range 200-399: Median Loss 0.000871 at epoch 303, Median Validation Loss 0.000907 at epoch 286
# He_1 Range 400-599: Median Loss 0.000811 at epoch 489, Median Validation Loss 0.000859 at epoch 530
# He_1 Range 600-799: Median Loss 0.000768 at epoch 713, Median Validation Loss 0.000827 at epoch 674
# He_1 Range 800-999: Median Loss 0.000742 at epoch 902, Median Validation Loss 0.000806 at epoch 831
# He_1 Range 1000-1199: Median Loss 0.000721 at epoch 1192, Median Validation Loss 0.000790 at epoch 1008
# He_1 Range 1200-1399: Median Loss 0.000705 at epoch 1235, Median Validation Loss 0.000777 at epoch 1233
# He_1 Range 1400-1599: Median Loss 0.000696 at epoch 1470, Median Validation Loss 0.000772 at epoch 1467
# He_1 Range 1600-1799: Median Loss 0.000686 at epoch 1628, Median Validation Loss 0.000763 at epoch 1665
# He_1 Range 1800-1999: Median Loss 0.000679 at epoch 1944, Median Validation Loss 0.000758 at epoch 1953
#
# Results for Model_5 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001081 at epoch 68, Median Validation Loss 0.001086 at epoch 78
# RS_1 Range 200-399: Median Loss 0.000939 at epoch 281, Median Validation Loss 0.000957 at epoch 372
# RS_1 Range 400-599: Median Loss 0.000867 at epoch 500, Median Validation Loss 0.000900 at epoch 505
# RS_1 Range 600-799: Median Loss 0.000819 at epoch 696, Median Validation Loss 0.000858 at epoch 663
# RS_1 Range 800-999: Median Loss 0.000787 at epoch 898, Median Validation Loss 0.000832 at epoch 813
# RS_1 Range 1000-1199: Median Loss 0.000766 at epoch 1086, Median Validation Loss 0.000821 at epoch 1088
# RS_1 Range 1200-1399: Median Loss 0.000743 at epoch 1289, Median Validation Loss 0.000804 at epoch 1203
# RS_1 Range 1400-1599: Median Loss 0.000724 at epoch 1497, Median Validation Loss 0.000788 at epoch 1431
# RS_1 Range 1600-1799: Median Loss 0.000707 at epoch 1795, Median Validation Loss 0.000776 at epoch 1747
# RS_1 Range 1800-1999: Median Loss 0.000695 at epoch 1876, Median Validation Loss 0.000769 at epoch 1851
# Results for Model_5 (He_1):
# He_1 Range 0-199: Median Loss 0.001051 at epoch 99, Median Validation Loss 0.001071 at epoch 100
# He_1 Range 200-399: Median Loss 0.000922 at epoch 299, Median Validation Loss 0.000980 at epoch 277
# He_1 Range 400-599: Median Loss 0.000857 at epoch 498, Median Validation Loss 0.000951 at epoch 486
# He_1 Range 600-799: Median Loss 0.000814 at epoch 697, Median Validation Loss 0.000940 at epoch 731
# He_1 Range 800-999: Median Loss 0.000781 at epoch 900, Median Validation Loss 0.000937 at epoch 902
# He_1 Range 1000-1199: Median Loss 0.000755 at epoch 1100, Median Validation Loss 0.000938 at epoch 1161
# He_1 Range 1200-1399: Median Loss 0.000733 at epoch 1290, Median Validation Loss 0.000940 at epoch 1254
# He_1 Range 1400-1599: Median Loss 0.000713 at epoch 1501, Median Validation Loss 0.000943 at epoch 1518
# He_1 Range 1600-1799: Median Loss 0.000696 at epoch 1685, Median Validation Loss 0.000946 at epoch 1657
# He_1 Range 1800-1999: Median Loss 0.000682 at epoch 1892, Median Validation Loss 0.000950 at epoch 1811
#
# Results for Model_6 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001126 at epoch 99, Median Validation Loss 0.001138 at epoch 99
# RS_1 Range 200-399: Median Loss 0.001007 at epoch 299, Median Validation Loss 0.001028 at epoch 288
# RS_1 Range 400-599: Median Loss 0.000936 at epoch 499, Median Validation Loss 0.000967 at epoch 477
# RS_1 Range 600-799: Median Loss 0.000896 at epoch 693, Median Validation Loss 0.000935 at epoch 693
# RS_1 Range 800-999: Median Loss 0.000869 at epoch 891, Median Validation Loss 0.000912 at epoch 892
# RS_1 Range 1000-1199: Median Loss 0.000848 at epoch 1073, Median Validation Loss 0.000898 at epoch 1039
# RS_1 Range 1200-1399: Median Loss 0.000832 at epoch 1304, Median Validation Loss 0.000885 at epoch 1228
# RS_1 Range 1400-1599: Median Loss 0.000818 at epoch 1461, Median Validation Loss 0.000873 at epoch 1513
# RS_1 Range 1600-1799: Median Loss 0.000806 at epoch 1705, Median Validation Loss 0.000864 at epoch 1722
# RS_1 Range 1800-1999: Median Loss 0.000795 at epoch 1963, Median Validation Loss 0.000855 at epoch 1953
# Results for Model_6 (He_1):
# He_1 Range 0-199: Median Loss 0.001140 at epoch 100, Median Validation Loss 0.001147 at epoch 99
# He_1 Range 200-399: Median Loss 0.001032 at epoch 299, Median Validation Loss 0.001051 at epoch 289
# He_1 Range 400-599: Median Loss 0.000976 at epoch 497, Median Validation Loss 0.001007 at epoch 508
# He_1 Range 600-799: Median Loss 0.000939 at epoch 702, Median Validation Loss 0.000982 at epoch 704
# He_1 Range 800-999: Median Loss 0.000911 at epoch 899, Median Validation Loss 0.000965 at epoch 970
# He_1 Range 1000-1199: Median Loss 0.000888 at epoch 1107, Median Validation Loss 0.000950 at epoch 1028
# He_1 Range 1200-1399: Median Loss 0.000870 at epoch 1290, Median Validation Loss 0.000940 at epoch 1303
# He_1 Range 1400-1599: Median Loss 0.000855 at epoch 1476, Median Validation Loss 0.000932 at epoch 1474
# He_1 Range 1600-1799: Median Loss 0.000843 at epoch 1685, Median Validation Loss 0.000925 at epoch 1683
# He_1 Range 1800-1999: Median Loss 0.000832 at epoch 1871, Median Validation Loss 0.000919 at epoch 1861
#
# Results for Model_7 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001108 at epoch 99, Median Validation Loss 0.001115 at epoch 97
# RS_1 Range 200-399: Median Loss 0.000989 at epoch 299, Median Validation Loss 0.001005 at epoch 298
# RS_1 Range 400-599: Median Loss 0.000937 at epoch 496, Median Validation Loss 0.000956 at epoch 488
# RS_1 Range 600-799: Median Loss 0.000897 at epoch 702, Median Validation Loss 0.000921 at epoch 679
# RS_1 Range 800-999: Median Loss 0.000867 at epoch 886, Median Validation Loss 0.000893 at epoch 866
# RS_1 Range 1000-1199: Median Loss 0.000847 at epoch 1104, Median Validation Loss 0.000873 at epoch 1064
# RS_1 Range 1200-1399: Median Loss 0.000831 at epoch 1247, Median Validation Loss 0.000858 at epoch 1257
# RS_1 Range 1400-1599: Median Loss 0.000817 at epoch 1467, Median Validation Loss 0.000843 at epoch 1448
# RS_1 Range 1600-1799: Median Loss 0.000807 at epoch 1614, Median Validation Loss 0.000833 at epoch 1658
# RS_1 Range 1800-1999: Median Loss 0.000796 at epoch 1845, Median Validation Loss 0.000824 at epoch 1845
# Results for Model_7 (He_1):
# He_1 Range 0-199: Median Loss 0.001121 at epoch 100, Median Validation Loss 0.001134 at epoch 88
# He_1 Range 200-399: Median Loss 0.001011 at epoch 300, Median Validation Loss 0.001033 at epoch 281
# He_1 Range 400-599: Median Loss 0.000946 at epoch 498, Median Validation Loss 0.000983 at epoch 539
# He_1 Range 600-799: Median Loss 0.000907 at epoch 699, Median Validation Loss 0.000952 at epoch 680
# He_1 Range 800-999: Median Loss 0.000881 at epoch 907, Median Validation Loss 0.000934 at epoch 880
# He_1 Range 1000-1199: Median Loss 0.000861 at epoch 1118, Median Validation Loss 0.000920 at epoch 1028
# He_1 Range 1200-1399: Median Loss 0.000845 at epoch 1286, Median Validation Loss 0.000906 at epoch 1233
# He_1 Range 1400-1599: Median Loss 0.000831 at epoch 1488, Median Validation Loss 0.000898 at epoch 1405
# He_1 Range 1600-1799: Median Loss 0.000817 at epoch 1682, Median Validation Loss 0.000890 at epoch 1603
# He_1 Range 1800-1999: Median Loss 0.000807 at epoch 1811, Median Validation Loss 0.000882 at epoch 1861
#
# Results for Model_8 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001128 at epoch 100, Median Validation Loss 0.001131 at epoch 97
# RS_1 Range 200-399: Median Loss 0.001010 at epoch 298, Median Validation Loss 0.001021 at epoch 293
# RS_1 Range 400-599: Median Loss 0.000945 at epoch 496, Median Validation Loss 0.000960 at epoch 497
# RS_1 Range 600-799: Median Loss 0.000912 at epoch 691, Median Validation Loss 0.000928 at epoch 722
# RS_1 Range 800-999: Median Loss 0.000887 at epoch 892, Median Validation Loss 0.000904 at epoch 860
# RS_1 Range 1000-1199: Median Loss 0.000869 at epoch 1062, Median Validation Loss 0.000888 at epoch 1067
# RS_1 Range 1200-1399: Median Loss 0.000853 at epoch 1263, Median Validation Loss 0.000873 at epoch 1370
# RS_1 Range 1400-1599: Median Loss 0.000838 at epoch 1505, Median Validation Loss 0.000859 at epoch 1501
# RS_1 Range 1600-1799: Median Loss 0.000826 at epoch 1721, Median Validation Loss 0.000848 at epoch 1607
# RS_1 Range 1800-1999: Median Loss 0.000816 at epoch 1835, Median Validation Loss 0.000839 at epoch 1984
# Results for Model_8 (He_1):
# He_1 Range 0-199: Median Loss 0.001113 at epoch 100, Median Validation Loss 0.001122 at epoch 95
# He_1 Range 200-399: Median Loss 0.000993 at epoch 298, Median Validation Loss 0.001012 at epoch 277
# He_1 Range 400-599: Median Loss 0.000946 at epoch 509, Median Validation Loss 0.000965 at epoch 527
# He_1 Range 600-799: Median Loss 0.000917 at epoch 672, Median Validation Loss 0.000939 at epoch 620
# He_1 Range 800-999: Median Loss 0.000894 at epoch 846, Median Validation Loss 0.000918 at epoch 887
# He_1 Range 1000-1199: Median Loss 0.000875 at epoch 1123, Median Validation Loss 0.000899 at epoch 1184
# He_1 Range 1200-1399: Median Loss 0.000864 at epoch 1368, Median Validation Loss 0.000889 at epoch 1269
# He_1 Range 1400-1599: Median Loss 0.000854 at epoch 1425, Median Validation Loss 0.000880 at epoch 1459
# He_1 Range 1600-1799: Median Loss 0.000845 at epoch 1653, Median Validation Loss 0.000870 at epoch 1602
# He_1 Range 1800-1999: Median Loss 0.000836 at epoch 1958, Median Validation Loss 0.000860 at epoch 1804
#
# Results for Model_9 (RS_1):
# RS_1 Range 0-199: Median Loss 0.001031 at epoch 100, Median Validation Loss 0.001045 at epoch 99
# RS_1 Range 200-399: Median Loss 0.000888 at epoch 301, Median Validation Loss 0.000933 at epoch 293
# RS_1 Range 400-599: Median Loss 0.000823 at epoch 488, Median Validation Loss 0.000888 at epoch 478
# RS_1 Range 600-799: Median Loss 0.000782 at epoch 688, Median Validation Loss 0.000867 at epoch 677
# RS_1 Range 800-999: Median Loss 0.000757 at epoch 969, Median Validation Loss 0.000854 at epoch 836
# RS_1 Range 1000-1199: Median Loss 0.000732 at epoch 1059, Median Validation Loss 0.000843 at epoch 1079
# RS_1 Range 1200-1399: Median Loss 0.000715 at epoch 1348, Median Validation Loss 0.000836 at epoch 1227
# RS_1 Range 1400-1599: Median Loss 0.000704 at epoch 1510, Median Validation Loss 0.000830 at epoch 1523
# RS_1 Range 1600-1799: Median Loss 0.000692 at epoch 1651, Median Validation Loss 0.000824 at epoch 1689
# RS_1 Range 1800-1999: Median Loss 0.000682 at epoch 1802, Median Validation Loss 0.000820 at epoch 1870
# Results for Model_9 (He_1):
# He_1 Range 0-199: Median Loss 0.001112 at epoch 98, Median Validation Loss 0.001121 at epoch 94
# He_1 Range 200-399: Median Loss 0.000998 at epoch 302, Median Validation Loss 0.001015 at epoch 295
# He_1 Range 400-599: Median Loss 0.000968 at epoch 440, Median Validation Loss 0.000990 at epoch 410
# He_1 Range 600-799: Median Loss 0.000954 at epoch 602, Median Validation Loss 0.000976 at epoch 761
# He_1 Range 800-999: Median Loss 0.000966 at epoch 998, Median Validation Loss 0.000987 at epoch 872
# He_1 Range 1000-1199: Median Loss 0.000942 at epoch 1192, Median Validation Loss 0.000966 at epoch 1059
# He_1 Range 1200-1399: Median Loss 0.000952 at epoch 1266, Median Validation Loss 0.000978 at epoch 1236
# He_1 Range 1400-1599: Median Loss 0.000914 at epoch 1480, Median Validation Loss 0.000950 at epoch 1471
# He_1 Range 1600-1799: Median Loss 0.000844 at epoch 1698, Median Validation Loss 0.000910 at epoch 1676
# He_1 Range 1800-1999: Median Loss 0.000799 at epoch 1904, Median Validation Loss 0.000884 at epoch 1875

# %%
import os
import pandas as pd
import numpy as np

# Base directory paths
base_path_rs_1 = 'AE_Testing_RS_1'
base_path_rs_he = 'AE_Testing_RS_He'

# Number of models
num_models = 9

# Epoch ranges for median and standard deviation calculations
epoch_ranges = [(0, 199), (200, 399), (400, 599), (600, 799),
                (800, 999), (1000, 1199), (1200, 1399), (1400, 1599),
                (1600, 1799), (1800, 1999)]

# Function to read the entire CSV and return training history data
def get_training_data(file_path):
    return pd.read_csv(file_path)

# Function to print median and standard deviation of loss and validation loss values
def print_statistics(df, range_start, range_end, label_prefix):
    range_df = df.iloc[range_start:range_end+1]
    median_loss = np.median(range_df['loss'])
    median_val_loss = np.median(range_df['val_loss'])

    # Find indices of the closest values to the median if exact match is not found
    median_loss_epoch = (np.abs(range_df['loss'] - median_loss)).idxmin()
    median_val_loss_epoch = (np.abs(range_df['val_loss'] - median_val_loss)).idxmin()

    # Calculate standard deviations
    std_loss = np.std(range_df['loss'])
    std_val_loss = np.std(range_df['val_loss'])

    print(f"{label_prefix} Range {range_start}-{range_end}:")
    print(f"- Median Loss {median_loss:.6f} at epoch {median_loss_epoch}, Std Dev {std_loss:.6f}")
    print(f"- Median Validation Loss {median_val_loss:.6f} at epoch {median_val_loss_epoch}, Std Dev {std_val_loss:.6f}")

# Analyze and print values for each model and range
for model_num in range(1, num_models + 1):
    model_folder_name = f'Model_{model_num}'
    file_rs_1 = os.path.join(base_path_rs_1, model_folder_name, 'Training_History.csv')
    file_rs_he = os.path.join(base_path_rs_he, model_folder_name, 'Training_History.csv')
    
    # Fetch full data set for each file
    data_rs_1 = get_training_data(file_rs_1)
    data_rs_he = get_training_data(file_rs_he)

    # Print statistics for both RS_1 and RS_He
    print(f"\nResults for {model_folder_name} (RS_1):")
    for start, end in epoch_ranges:
        print_statistics(data_rs_1, start, end, "RS_1")
    print(f"\nResults for {model_folder_name} (He_1):")
    for start, end in epoch_ranges:
        print_statistics(data_rs_he, start, end, "He_1")
# Out:
# Results for Model_1 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001060 at epoch 99, Std Dev 0.000244
# - Median Validation Loss 0.001059 at epoch 99, Std Dev 0.000116
# RS_1 Range 200-399:
# - Median Loss 0.000932 at epoch 301, Std Dev 0.000024
# - Median Validation Loss 0.000956 at epoch 296, Std Dev 0.000017
# RS_1 Range 400-599:
# - Median Loss 0.000868 at epoch 501, Std Dev 0.000014
# - Median Validation Loss 0.000914 at epoch 493, Std Dev 0.000009
# RS_1 Range 600-799:
# - Median Loss 0.000828 at epoch 697, Std Dev 0.000010
# - Median Validation Loss 0.000892 at epoch 739, Std Dev 0.000005
# RS_1 Range 800-999:
# - Median Loss 0.000800 at epoch 893, Std Dev 0.000007
# - Median Validation Loss 0.000880 at epoch 900, Std Dev 0.000004
# RS_1 Range 1000-1199:
# - Median Loss 0.000779 at epoch 1098, Std Dev 0.000005
# - Median Validation Loss 0.000872 at epoch 1132, Std Dev 0.000003
# RS_1 Range 1200-1399:
# - Median Loss 0.000762 at epoch 1287, Std Dev 0.000005
# - Median Validation Loss 0.000868 at epoch 1221, Std Dev 0.000003
# RS_1 Range 1400-1599:
# - Median Loss 0.000746 at epoch 1489, Std Dev 0.000004
# - Median Validation Loss 0.000865 at epoch 1463, Std Dev 0.000002
# RS_1 Range 1600-1799:
# - Median Loss 0.000733 at epoch 1704, Std Dev 0.000004
# - Median Validation Loss 0.000864 at epoch 1733, Std Dev 0.000002
# RS_1 Range 1800-1999:
# - Median Loss 0.000720 at epoch 1897, Std Dev 0.000004
# - Median Validation Loss 0.000864 at epoch 1871, Std Dev 0.000003
#
# Results for Model_1 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001013 at epoch 96, Std Dev 0.000021
# - Median Validation Loss 0.001080 at epoch 126, Std Dev 0.000017
# He_1 Range 200-399:
# - Median Loss 0.000951 at epoch 297, Std Dev 0.000015
# - Median Validation Loss 0.001043 at epoch 261, Std Dev 0.000009
# He_1 Range 400-599:
# - Median Loss 0.000907 at epoch 498, Std Dev 0.000011
# - Median Validation Loss 0.001028 at epoch 453, Std Dev 0.000006
# He_1 Range 600-799:
# - Median Loss 0.000873 at epoch 700, Std Dev 0.000009
# - Median Validation Loss 0.001021 at epoch 786, Std Dev 0.000004
# He_1 Range 800-999:
# - Median Loss 0.000844 at epoch 899, Std Dev 0.000008
# - Median Validation Loss 0.001020 at epoch 953, Std Dev 0.000003
# He_1 Range 1000-1199:
# - Median Loss 0.000821 at epoch 1106, Std Dev 0.000006
# - Median Validation Loss 0.001022 at epoch 1138, Std Dev 0.000004
# He_1 Range 1200-1399:
# - Median Loss 0.000801 at epoch 1303, Std Dev 0.000005
# - Median Validation Loss 0.001024 at epoch 1248, Std Dev 0.000004
# He_1 Range 1400-1599:
# - Median Loss 0.000783 at epoch 1492, Std Dev 0.000005
# - Median Validation Loss 0.001028 at epoch 1427, Std Dev 0.000003
# He_1 Range 1600-1799:
# - Median Loss 0.000769 at epoch 1692, Std Dev 0.000004
# - Median Validation Loss 0.001032 at epoch 1779, Std Dev 0.000003
# He_1 Range 1800-1999:
# - Median Loss 0.000756 at epoch 1892, Std Dev 0.000003
# - Median Validation Loss 0.001035 at epoch 1885, Std Dev 0.000003
#
# Results for Model_2 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001045 at epoch 96, Std Dev 0.000432
# - Median Validation Loss 0.001046 at epoch 91, Std Dev 0.000295
# RS_1 Range 200-399:
# - Median Loss 0.000950 at epoch 206, Std Dev 0.000034
# - Median Validation Loss 0.000960 at epoch 354, Std Dev 0.000034
# RS_1 Range 400-599:
# - Median Loss 0.000878 at epoch 468, Std Dev 0.000019
# - Median Validation Loss 0.000899 at epoch 505, Std Dev 0.000019
# RS_1 Range 600-799:
# - Median Loss 0.000843 at epoch 612, Std Dev 0.000010
# - Median Validation Loss 0.000869 at epoch 624, Std Dev 0.000011
# RS_1 Range 800-999:
# - Median Loss 0.000818 at epoch 837, Std Dev 0.000010
# - Median Validation Loss 0.000850 at epoch 904, Std Dev 0.000014
# RS_1 Range 1000-1199:
# - Median Loss 0.000792 at epoch 1071, Std Dev 0.000011
# - Median Validation Loss 0.000834 at epoch 1105, Std Dev 0.000011
# RS_1 Range 1200-1399:
# - Median Loss 0.000762 at epoch 1257, Std Dev 0.000010
# - Median Validation Loss 0.000813 at epoch 1296, Std Dev 0.000009
# RS_1 Range 1400-1599:
# - Median Loss 0.000742 at epoch 1412, Std Dev 0.000012
# - Median Validation Loss 0.000798 at epoch 1588, Std Dev 0.000011
# RS_1 Range 1600-1799:
# - Median Loss 0.000724 at epoch 1695, Std Dev 0.000010
# - Median Validation Loss 0.000786 at epoch 1619, Std Dev 0.000011
# RS_1 Range 1800-1999:
# - Median Loss 0.000707 at epoch 1956, Std Dev 0.000009
# - Median Validation Loss 0.000777 at epoch 1963, Std Dev 0.000010
#
# Results for Model_2 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.000932 at epoch 99, Std Dev 0.000023
# - Median Validation Loss 0.000997 at epoch 105, Std Dev 0.000017
# He_1 Range 200-399:
# - Median Loss 0.000868 at epoch 300, Std Dev 0.000017
# - Median Validation Loss 0.000958 at epoch 270, Std Dev 0.000010
# He_1 Range 400-599:
# - Median Loss 0.000816 at epoch 495, Std Dev 0.000013
# - Median Validation Loss 0.000937 at epoch 509, Std Dev 0.000005
# He_1 Range 600-799:
# - Median Loss 0.000778 at epoch 697, Std Dev 0.000010
# - Median Validation Loss 0.000927 at epoch 639, Std Dev 0.000004
# He_1 Range 800-999:
# - Median Loss 0.000748 at epoch 898, Std Dev 0.000008
# - Median Validation Loss 0.000922 at epoch 909, Std Dev 0.000004
# He_1 Range 1000-1199:
# - Median Loss 0.000722 at epoch 1104, Std Dev 0.000007
# - Median Validation Loss 0.000920 at epoch 1124, Std Dev 0.000003
# He_1 Range 1200-1399:
# - Median Loss 0.000700 at epoch 1300, Std Dev 0.000006
# - Median Validation Loss 0.000920 at epoch 1349, Std Dev 0.000003
# He_1 Range 1400-1599:
# - Median Loss 0.000680 at epoch 1501, Std Dev 0.000005
# - Median Validation Loss 0.000923 at epoch 1583, Std Dev 0.000003
# He_1 Range 1600-1799:
# - Median Loss 0.000662 at epoch 1700, Std Dev 0.000005
# - Median Validation Loss 0.000927 at epoch 1691, Std Dev 0.000003
# He_1 Range 1800-1999:
# - Median Loss 0.000647 at epoch 1882, Std Dev 0.000004
# - Median Validation Loss 0.000931 at epoch 1937, Std Dev 0.000003
#
# Results for Model_3 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001076 at epoch 99, Std Dev 0.000317
# - Median Validation Loss 0.001081 at epoch 99, Std Dev 0.000117
# RS_1 Range 200-399:
# - Median Loss 0.000949 at epoch 295, Std Dev 0.000023
# - Median Validation Loss 0.000963 at epoch 311, Std Dev 0.000022
# RS_1 Range 400-599:
# - Median Loss 0.000896 at epoch 470, Std Dev 0.000011
# - Median Validation Loss 0.000911 at epoch 458, Std Dev 0.000013
# RS_1 Range 600-799:
# - Median Loss 0.000863 at epoch 749, Std Dev 0.000008
# - Median Validation Loss 0.000878 at epoch 660, Std Dev 0.000010
# RS_1 Range 800-999:
# - Median Loss 0.000842 at epoch 879, Std Dev 0.000007
# - Median Validation Loss 0.000858 at epoch 976, Std Dev 0.000010
# RS_1 Range 1000-1199:
# - Median Loss 0.000828 at epoch 1063, Std Dev 0.000009
# - Median Validation Loss 0.000845 at epoch 1096, Std Dev 0.000015
# RS_1 Range 1200-1399:
# - Median Loss 0.000811 at epoch 1306, Std Dev 0.000007
# - Median Validation Loss 0.000830 at epoch 1222, Std Dev 0.000009
# RS_1 Range 1400-1599:
# - Median Loss 0.000801 at epoch 1453, Std Dev 0.000007
# - Median Validation Loss 0.000820 at epoch 1447, Std Dev 0.000009
# RS_1 Range 1600-1799:
# - Median Loss 0.000795 at epoch 1664, Std Dev 0.000012
# - Median Validation Loss 0.000813 at epoch 1640, Std Dev 0.000018
# RS_1 Range 1800-1999:
# - Median Loss 0.000782 at epoch 1848, Std Dev 0.000008
# - Median Validation Loss 0.000802 at epoch 1811, Std Dev 0.000013
#
# Results for Model_3 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001092 at epoch 99, Std Dev 0.000451
# - Median Validation Loss 0.001103 at epoch 99, Std Dev 0.000123
# He_1 Range 200-399:
# - Median Loss 0.000968 at epoch 296, Std Dev 0.000023
# - Median Validation Loss 0.000992 at epoch 333, Std Dev 0.000020
# He_1 Range 400-599:
# - Median Loss 0.000914 at epoch 490, Std Dev 0.000011
# - Median Validation Loss 0.000937 at epoch 467, Std Dev 0.000013
# He_1 Range 600-799:
# - Median Loss 0.000882 at epoch 675, Std Dev 0.000009
# - Median Validation Loss 0.000909 at epoch 672, Std Dev 0.000009
# He_1 Range 800-999:
# - Median Loss 0.000859 at epoch 865, Std Dev 0.000008
# - Median Validation Loss 0.000890 at epoch 903, Std Dev 0.000009
# He_1 Range 1000-1199:
# - Median Loss 0.000841 at epoch 1079, Std Dev 0.000007
# - Median Validation Loss 0.000872 at epoch 1109, Std Dev 0.000010
# He_1 Range 1200-1399:
# - Median Loss 0.000829 at epoch 1212, Std Dev 0.000008
# - Median Validation Loss 0.000861 at epoch 1268, Std Dev 0.000010
# He_1 Range 1400-1599:
# - Median Loss 0.000814 at epoch 1446, Std Dev 0.000008
# - Median Validation Loss 0.000848 at epoch 1489, Std Dev 0.000011
# He_1 Range 1600-1799:
# - Median Loss 0.000805 at epoch 1651, Std Dev 0.000008
# - Median Validation Loss 0.000841 at epoch 1613, Std Dev 0.000010
# He_1 Range 1800-1999:
# - Median Loss 0.000793 at epoch 1870, Std Dev 0.000012
# - Median Validation Loss 0.000830 at epoch 1905, Std Dev 0.000013
#
# Results for Model_4 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001015 at epoch 100, Std Dev 0.000373
# - Median Validation Loss 0.001030 at epoch 97, Std Dev 0.000198
# RS_1 Range 200-399:
# - Median Loss 0.000866 at epoch 310, Std Dev 0.000026
# - Median Validation Loss 0.000904 at epoch 287, Std Dev 0.000022
# RS_1 Range 400-599:
# - Median Loss 0.000807 at epoch 491, Std Dev 0.000013
# - Median Validation Loss 0.000853 at epoch 487, Std Dev 0.000012
# RS_1 Range 600-799:
# - Median Loss 0.000777 at epoch 653, Std Dev 0.000009
# - Median Validation Loss 0.000822 at epoch 647, Std Dev 0.000010
# RS_1 Range 800-999:
# - Median Loss 0.000752 at epoch 834, Std Dev 0.000009
# - Median Validation Loss 0.000797 at epoch 902, Std Dev 0.000010
# RS_1 Range 1000-1199:
# - Median Loss 0.000734 at epoch 1053, Std Dev 0.000007
# - Median Validation Loss 0.000779 at epoch 1028, Std Dev 0.000009
# RS_1 Range 1200-1399:
# - Median Loss 0.000718 at epoch 1384, Std Dev 0.000008
# - Median Validation Loss 0.000763 at epoch 1367, Std Dev 0.000009
# RS_1 Range 1400-1599:
# - Median Loss 0.000705 at epoch 1594, Std Dev 0.000011
# - Median Validation Loss 0.000749 at epoch 1483, Std Dev 0.000011
# RS_1 Range 1600-1799:
# - Median Loss 0.000697 at epoch 1650, Std Dev 0.000015
# - Median Validation Loss 0.000743 at epoch 1655, Std Dev 0.000017
# RS_1 Range 1800-1999:
# - Median Loss 0.000689 at epoch 1806, Std Dev 0.000017
# - Median Validation Loss 0.000733 at epoch 1802, Std Dev 0.000018
#
# Results for Model_4 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001013 at epoch 101, Std Dev 0.000252
# - Median Validation Loss 0.001031 at epoch 94, Std Dev 0.000113
# He_1 Range 200-399:
# - Median Loss 0.000871 at epoch 303, Std Dev 0.000026
# - Median Validation Loss 0.000907 at epoch 286, Std Dev 0.000021
# He_1 Range 400-599:
# - Median Loss 0.000811 at epoch 489, Std Dev 0.000015
# - Median Validation Loss 0.000859 at epoch 530, Std Dev 0.000014
# He_1 Range 600-799:
# - Median Loss 0.000768 at epoch 713, Std Dev 0.000010
# - Median Validation Loss 0.000827 at epoch 674, Std Dev 0.000011
# He_1 Range 800-999:
# - Median Loss 0.000742 at epoch 902, Std Dev 0.000008
# - Median Validation Loss 0.000806 at epoch 831, Std Dev 0.000010
# He_1 Range 1000-1199:
# - Median Loss 0.000721 at epoch 1192, Std Dev 0.000009
# - Median Validation Loss 0.000790 at epoch 1008, Std Dev 0.000010
# He_1 Range 1200-1399:
# - Median Loss 0.000705 at epoch 1235, Std Dev 0.000008
# - Median Validation Loss 0.000777 at epoch 1233, Std Dev 0.000009
# He_1 Range 1400-1599:
# - Median Loss 0.000696 at epoch 1470, Std Dev 0.000010
# - Median Validation Loss 0.000772 at epoch 1467, Std Dev 0.000013
# He_1 Range 1600-1799:
# - Median Loss 0.000686 at epoch 1628, Std Dev 0.000011
# - Median Validation Loss 0.000763 at epoch 1665, Std Dev 0.000012
# He_1 Range 1800-1999:
# - Median Loss 0.000679 at epoch 1944, Std Dev 0.000016
# - Median Validation Loss 0.000758 at epoch 1953, Std Dev 0.000019
#
# Results for Model_5 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001081 at epoch 68, Std Dev 0.000410
# - Median Validation Loss 0.001086 at epoch 78, Std Dev 0.000285
# RS_1 Range 200-399:
# - Median Loss 0.000939 at epoch 281, Std Dev 0.000028
# - Median Validation Loss 0.000957 at epoch 372, Std Dev 0.000030
# RS_1 Range 400-599:
# - Median Loss 0.000867 at epoch 500, Std Dev 0.000026
# - Median Validation Loss 0.000900 at epoch 505, Std Dev 0.000023
# RS_1 Range 600-799:
# - Median Loss 0.000819 at epoch 696, Std Dev 0.000012
# - Median Validation Loss 0.000858 at epoch 663, Std Dev 0.000012
# RS_1 Range 800-999:
# - Median Loss 0.000787 at epoch 898, Std Dev 0.000009
# - Median Validation Loss 0.000832 at epoch 813, Std Dev 0.000010
# RS_1 Range 1000-1199:
# - Median Loss 0.000766 at epoch 1086, Std Dev 0.000011
# - Median Validation Loss 0.000821 at epoch 1088, Std Dev 0.000009
# RS_1 Range 1200-1399:
# - Median Loss 0.000743 at epoch 1289, Std Dev 0.000011
# - Median Validation Loss 0.000804 at epoch 1203, Std Dev 0.000011
# RS_1 Range 1400-1599:
# - Median Loss 0.000724 at epoch 1497, Std Dev 0.000013
# - Median Validation Loss 0.000788 at epoch 1431, Std Dev 0.000015
# RS_1 Range 1600-1799:
# - Median Loss 0.000707 at epoch 1795, Std Dev 0.000011
# - Median Validation Loss 0.000776 at epoch 1747, Std Dev 0.000013
# RS_1 Range 1800-1999:
# - Median Loss 0.000695 at epoch 1876, Std Dev 0.000012
# - Median Validation Loss 0.000769 at epoch 1851, Std Dev 0.000015
#
# Results for Model_5 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001051 at epoch 99, Std Dev 0.000636
# - Median Validation Loss 0.001071 at epoch 100, Std Dev 0.000102
# He_1 Range 200-399:
# - Median Loss 0.000922 at epoch 299, Std Dev 0.000025
# - Median Validation Loss 0.000980 at epoch 277, Std Dev 0.000014
# He_1 Range 400-599:
# - Median Loss 0.000857 at epoch 498, Std Dev 0.000015
# - Median Validation Loss 0.000951 at epoch 486, Std Dev 0.000007
# He_1 Range 600-799:
# - Median Loss 0.000814 at epoch 697, Std Dev 0.000011
# - Median Validation Loss 0.000940 at epoch 731, Std Dev 0.000004
# He_1 Range 800-999:
# - Median Loss 0.000781 at epoch 900, Std Dev 0.000008
# - Median Validation Loss 0.000937 at epoch 902, Std Dev 0.000003
# He_1 Range 1000-1199:
# - Median Loss 0.000755 at epoch 1100, Std Dev 0.000007
# - Median Validation Loss 0.000938 at epoch 1161, Std Dev 0.000003
# He_1 Range 1200-1399:
# - Median Loss 0.000733 at epoch 1290, Std Dev 0.000006
# - Median Validation Loss 0.000940 at epoch 1254, Std Dev 0.000003
# He_1 Range 1400-1599:
# - Median Loss 0.000713 at epoch 1501, Std Dev 0.000005
# - Median Validation Loss 0.000943 at epoch 1518, Std Dev 0.000003
# He_1 Range 1600-1799:
# - Median Loss 0.000696 at epoch 1685, Std Dev 0.000004
# - Median Validation Loss 0.000946 at epoch 1657, Std Dev 0.000003
# He_1 Range 1800-1999:
# - Median Loss 0.000682 at epoch 1892, Std Dev 0.000004
# - Median Validation Loss 0.000950 at epoch 1811, Std Dev 0.000003
#
# Results for Model_6 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001126 at epoch 99, Std Dev 0.000448
# - Median Validation Loss 0.001138 at epoch 99, Std Dev 0.000174
# RS_1 Range 200-399:
# - Median Loss 0.001007 at epoch 299, Std Dev 0.000027
# - Median Validation Loss 0.001028 at epoch 288, Std Dev 0.000024
# RS_1 Range 400-599:
# - Median Loss 0.000936 at epoch 499, Std Dev 0.000015
# - Median Validation Loss 0.000967 at epoch 477, Std Dev 0.000013
# RS_1 Range 600-799:
# - Median Loss 0.000896 at epoch 693, Std Dev 0.000010
# - Median Validation Loss 0.000935 at epoch 693, Std Dev 0.000008
# RS_1 Range 800-999:
# - Median Loss 0.000869 at epoch 891, Std Dev 0.000007
# - Median Validation Loss 0.000912 at epoch 892, Std Dev 0.000006
# RS_1 Range 1000-1199:
# - Median Loss 0.000848 at epoch 1073, Std Dev 0.000005
# - Median Validation Loss 0.000898 at epoch 1039, Std Dev 0.000005
# RS_1 Range 1200-1399:
# - Median Loss 0.000832 at epoch 1304, Std Dev 0.000005
# - Median Validation Loss 0.000885 at epoch 1228, Std Dev 0.000004
# RS_1 Range 1400-1599:
# - Median Loss 0.000818 at epoch 1461, Std Dev 0.000005
# - Median Validation Loss 0.000873 at epoch 1513, Std Dev 0.000004
# RS_1 Range 1600-1799:
# - Median Loss 0.000806 at epoch 1705, Std Dev 0.000004
# - Median Validation Loss 0.000864 at epoch 1722, Std Dev 0.000004
# RS_1 Range 1800-1999:
# - Median Loss 0.000795 at epoch 1963, Std Dev 0.000004
# - Median Validation Loss 0.000855 at epoch 1953, Std Dev 0.000003
#
# Results for Model_6 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001140 at epoch 100, Std Dev 0.000415
# - Median Validation Loss 0.001147 at epoch 99, Std Dev 0.000129
# He_1 Range 200-399:
# - Median Loss 0.001032 at epoch 299, Std Dev 0.000023
# - Median Validation Loss 0.001051 at epoch 289, Std Dev 0.000019
# He_1 Range 400-599:
# - Median Loss 0.000976 at epoch 497, Std Dev 0.000013
# - Median Validation Loss 0.001007 at epoch 508, Std Dev 0.000010
# He_1 Range 600-799:
# - Median Loss 0.000939 at epoch 702, Std Dev 0.000009
# - Median Validation Loss 0.000982 at epoch 704, Std Dev 0.000007
# He_1 Range 800-999:
# - Median Loss 0.000911 at epoch 899, Std Dev 0.000007
# - Median Validation Loss 0.000965 at epoch 970, Std Dev 0.000006
# He_1 Range 1000-1199:
# - Median Loss 0.000888 at epoch 1107, Std Dev 0.000006
# - Median Validation Loss 0.000950 at epoch 1028, Std Dev 0.000004
# He_1 Range 1200-1399:
# - Median Loss 0.000870 at epoch 1290, Std Dev 0.000005
# - Median Validation Loss 0.000940 at epoch 1303, Std Dev 0.000004
# He_1 Range 1400-1599:
# - Median Loss 0.000855 at epoch 1476, Std Dev 0.000004
# - Median Validation Loss 0.000932 at epoch 1474, Std Dev 0.000004
# He_1 Range 1600-1799:
# - Median Loss 0.000843 at epoch 1685, Std Dev 0.000004
# - Median Validation Loss 0.000925 at epoch 1683, Std Dev 0.000004
# He_1 Range 1800-1999:
# - Median Loss 0.000832 at epoch 1871, Std Dev 0.000004
# - Median Validation Loss 0.000919 at epoch 1861, Std Dev 0.000004
#
# Results for Model_7 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001108 at epoch 99, Std Dev 0.000424
# - Median Validation Loss 0.001115 at epoch 97, Std Dev 0.000194
# RS_1 Range 200-399:
# - Median Loss 0.000989 at epoch 299, Std Dev 0.000021
# - Median Validation Loss 0.001005 at epoch 298, Std Dev 0.000020
# RS_1 Range 400-599:
# - Median Loss 0.000937 at epoch 496, Std Dev 0.000013
# - Median Validation Loss 0.000956 at epoch 488, Std Dev 0.000012
# RS_1 Range 600-799:
# - Median Loss 0.000897 at epoch 702, Std Dev 0.000010
# - Median Validation Loss 0.000921 at epoch 679, Std Dev 0.000010
# RS_1 Range 800-999:
# - Median Loss 0.000867 at epoch 886, Std Dev 0.000008
# - Median Validation Loss 0.000893 at epoch 866, Std Dev 0.000009
# RS_1 Range 1000-1199:
# - Median Loss 0.000847 at epoch 1104, Std Dev 0.000006
# - Median Validation Loss 0.000873 at epoch 1064, Std Dev 0.000006
# RS_1 Range 1200-1399:
# - Median Loss 0.000831 at epoch 1247, Std Dev 0.000006
# - Median Validation Loss 0.000858 at epoch 1257, Std Dev 0.000006
# RS_1 Range 1400-1599:
# - Median Loss 0.000817 at epoch 1467, Std Dev 0.000005
# - Median Validation Loss 0.000843 at epoch 1448, Std Dev 0.000007
# RS_1 Range 1600-1799:
# - Median Loss 0.000807 at epoch 1614, Std Dev 0.000005
# - Median Validation Loss 0.000833 at epoch 1658, Std Dev 0.000008
# RS_1 Range 1800-1999:
# - Median Loss 0.000796 at epoch 1845, Std Dev 0.000006
# - Median Validation Loss 0.000824 at epoch 1845, Std Dev 0.000008
#
# Results for Model_7 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001121 at epoch 100, Std Dev 0.000377
# - Median Validation Loss 0.001134 at epoch 88, Std Dev 0.000129
# He_1 Range 200-399:
# - Median Loss 0.001011 at epoch 300, Std Dev 0.000025
# - Median Validation Loss 0.001033 at epoch 281, Std Dev 0.000022
# He_1 Range 400-599:
# - Median Loss 0.000946 at epoch 498, Std Dev 0.000014
# - Median Validation Loss 0.000983 at epoch 539, Std Dev 0.000014
# He_1 Range 600-799:
# - Median Loss 0.000907 at epoch 699, Std Dev 0.000009
# - Median Validation Loss 0.000952 at epoch 680, Std Dev 0.000010
# He_1 Range 800-999:
# - Median Loss 0.000881 at epoch 907, Std Dev 0.000007
# - Median Validation Loss 0.000934 at epoch 880, Std Dev 0.000009
# He_1 Range 1000-1199:
# - Median Loss 0.000861 at epoch 1118, Std Dev 0.000007
# - Median Validation Loss 0.000920 at epoch 1028, Std Dev 0.000008
# He_1 Range 1200-1399:
# - Median Loss 0.000845 at epoch 1286, Std Dev 0.000007
# - Median Validation Loss 0.000906 at epoch 1233, Std Dev 0.000008
# He_1 Range 1400-1599:
# - Median Loss 0.000831 at epoch 1488, Std Dev 0.000006
# - Median Validation Loss 0.000898 at epoch 1405, Std Dev 0.000008
# He_1 Range 1600-1799:
# - Median Loss 0.000817 at epoch 1682, Std Dev 0.000006
# - Median Validation Loss 0.000890 at epoch 1603, Std Dev 0.000007
# He_1 Range 1800-1999:
# - Median Loss 0.000807 at epoch 1811, Std Dev 0.000006
# - Median Validation Loss 0.000882 at epoch 1861, Std Dev 0.000006
#
# Results for Model_8 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001128 at epoch 100, Std Dev 0.000476
# - Median Validation Loss 0.001131 at epoch 97, Std Dev 0.000249
# RS_1 Range 200-399:
# - Median Loss 0.001010 at epoch 298, Std Dev 0.000025
# - Median Validation Loss 0.001021 at epoch 293, Std Dev 0.000023
# RS_1 Range 400-599:
# - Median Loss 0.000945 at epoch 496, Std Dev 0.000013
# - Median Validation Loss 0.000960 at epoch 497, Std Dev 0.000013
# RS_1 Range 600-799:
# - Median Loss 0.000912 at epoch 691, Std Dev 0.000009
# - Median Validation Loss 0.000928 at epoch 722, Std Dev 0.000009
# RS_1 Range 800-999:
# - Median Loss 0.000887 at epoch 892, Std Dev 0.000007
# - Median Validation Loss 0.000904 at epoch 860, Std Dev 0.000008
# RS_1 Range 1000-1199:
# - Median Loss 0.000869 at epoch 1062, Std Dev 0.000006
# - Median Validation Loss 0.000888 at epoch 1067, Std Dev 0.000008
# RS_1 Range 1200-1399:
# - Median Loss 0.000853 at epoch 1263, Std Dev 0.000005
# - Median Validation Loss 0.000873 at epoch 1370, Std Dev 0.000007
# RS_1 Range 1400-1599:
# - Median Loss 0.000838 at epoch 1505, Std Dev 0.000005
# - Median Validation Loss 0.000859 at epoch 1501, Std Dev 0.000006
# RS_1 Range 1600-1799:
# - Median Loss 0.000826 at epoch 1721, Std Dev 0.000006
# - Median Validation Loss 0.000848 at epoch 1607, Std Dev 0.000006
# RS_1 Range 1800-1999:
# - Median Loss 0.000816 at epoch 1835, Std Dev 0.000006
# - Median Validation Loss 0.000839 at epoch 1984, Std Dev 0.000007
#
# Results for Model_8 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001113 at epoch 100, Std Dev 0.000360
# - Median Validation Loss 0.001122 at epoch 95, Std Dev 0.000122
# He_1 Range 200-399:
# - Median Loss 0.000993 at epoch 298, Std Dev 0.000020
# - Median Validation Loss 0.001012 at epoch 277, Std Dev 0.000020
# He_1 Range 400-599:
# - Median Loss 0.000946 at epoch 509, Std Dev 0.000010
# - Median Validation Loss 0.000965 at epoch 527, Std Dev 0.000012
# He_1 Range 600-799:
# - Median Loss 0.000917 at epoch 672, Std Dev 0.000009
# - Median Validation Loss 0.000939 at epoch 620, Std Dev 0.000012
# He_1 Range 800-999:
# - Median Loss 0.000894 at epoch 846, Std Dev 0.000008
# - Median Validation Loss 0.000918 at epoch 887, Std Dev 0.000011
# He_1 Range 1000-1199:
# - Median Loss 0.000875 at epoch 1123, Std Dev 0.000009
# - Median Validation Loss 0.000899 at epoch 1184, Std Dev 0.000012
# He_1 Range 1200-1399:
# - Median Loss 0.000864 at epoch 1368, Std Dev 0.000008
# - Median Validation Loss 0.000889 at epoch 1269, Std Dev 0.000011
# He_1 Range 1400-1599:
# - Median Loss 0.000854 at epoch 1425, Std Dev 0.000013
# - Median Validation Loss 0.000880 at epoch 1459, Std Dev 0.000015
# He_1 Range 1600-1799:
# - Median Loss 0.000845 at epoch 1653, Std Dev 0.000013
# - Median Validation Loss 0.000870 at epoch 1602, Std Dev 0.000013
# He_1 Range 1800-1999:
# - Median Loss 0.000836 at epoch 1958, Std Dev 0.000009
# - Median Validation Loss 0.000860 at epoch 1804, Std Dev 0.000012
#
# Results for Model_9 (RS_1):
# RS_1 Range 0-199:
# - Median Loss 0.001031 at epoch 100, Std Dev 0.000383
# - Median Validation Loss 0.001045 at epoch 99, Std Dev 0.000200
# RS_1 Range 200-399:
# - Median Loss 0.000888 at epoch 301, Std Dev 0.000025
# - Median Validation Loss 0.000933 at epoch 293, Std Dev 0.000018
# RS_1 Range 400-599:
# - Median Loss 0.000823 at epoch 488, Std Dev 0.000015
# - Median Validation Loss 0.000888 at epoch 478, Std Dev 0.000010
# RS_1 Range 600-799:
# - Median Loss 0.000782 at epoch 688, Std Dev 0.000010
# - Median Validation Loss 0.000867 at epoch 677, Std Dev 0.000007
# RS_1 Range 800-999:
# - Median Loss 0.000757 at epoch 969, Std Dev 0.000008
# - Median Validation Loss 0.000854 at epoch 836, Std Dev 0.000006
# RS_1 Range 1000-1199:
# - Median Loss 0.000732 at epoch 1059, Std Dev 0.000008
# - Median Validation Loss 0.000843 at epoch 1079, Std Dev 0.000005
# RS_1 Range 1200-1399:
# - Median Loss 0.000715 at epoch 1348, Std Dev 0.000006
# - Median Validation Loss 0.000836 at epoch 1227, Std Dev 0.000007
# RS_1 Range 1400-1599:
# - Median Loss 0.000704 at epoch 1510, Std Dev 0.000006
# - Median Validation Loss 0.000830 at epoch 1523, Std Dev 0.000005
# RS_1 Range 1600-1799:
# - Median Loss 0.000692 at epoch 1651, Std Dev 0.000006
# - Median Validation Loss 0.000824 at epoch 1689, Std Dev 0.000005
# RS_1 Range 1800-1999:
# - Median Loss 0.000682 at epoch 1802, Std Dev 0.000006
# - Median Validation Loss 0.000820 at epoch 1870, Std Dev 0.000004
#
# Results for Model_9 (He_1):
# He_1 Range 0-199:
# - Median Loss 0.001112 at epoch 98, Std Dev 0.000423
# - Median Validation Loss 0.001121 at epoch 94, Std Dev 0.000132
# He_1 Range 200-399:
# - Median Loss 0.000998 at epoch 302, Std Dev 0.000025
# - Median Validation Loss 0.001015 at epoch 295, Std Dev 0.000027
# He_1 Range 400-599:
# - Median Loss 0.000968 at epoch 440, Std Dev 0.000052
# - Median Validation Loss 0.000990 at epoch 410, Std Dev 0.000052
# He_1 Range 600-799:
# - Median Loss 0.000954 at epoch 602, Std Dev 0.000041
# - Median Validation Loss 0.000976 at epoch 761, Std Dev 0.000045
# He_1 Range 800-999:
# - Median Loss 0.000966 at epoch 998, Std Dev 0.000052
# - Median Validation Loss 0.000987 at epoch 872, Std Dev 0.000051
# He_1 Range 1000-1199:
# - Median Loss 0.000942 at epoch 1192, Std Dev 0.000033
# - Median Validation Loss 0.000966 at epoch 1059, Std Dev 0.000033
# He_1 Range 1200-1399:
# - Median Loss 0.000952 at epoch 1266, Std Dev 0.000026
# - Median Validation Loss 0.000978 at epoch 1236, Std Dev 0.000028
# He_1 Range 1400-1599:
# - Median Loss 0.000914 at epoch 1480, Std Dev 0.000018
# - Median Validation Loss 0.000950 at epoch 1471, Std Dev 0.000017
# He_1 Range 1600-1799:
# - Median Loss 0.000844 at epoch 1698, Std Dev 0.000019
# - Median Validation Loss 0.000910 at epoch 1676, Std Dev 0.000013
# He_1 Range 1800-1999:
# - Median Loss 0.000799 at epoch 1904, Std Dev 0.000011
# - Median Validation Loss 0.000884 at epoch 1875, Std Dev 0.000007

# %% [raw]
# I have two series of folders named: Model_[n] for n=1-9. One series is saved in a folder titled "AE_Testing_RS_1", and the other is saved in a folder titled "AE_Testing_RS_He". In each Model_[n] folder, there is a file titled "Training_History.csv". Within each Training_History.csv" file, there are 3 columns. The first has no title, and is the epoch number starting with epoch 0 in column A row 2. The second column is titled "loss" and contains the loss value for the epoch. The third column is titled "val_loss" and contains the validation loss for each epoch.
#
# I want to generate an overlaid graph for each model, where loss and validation loss are plotted for epochs 0-1999. I want Model_1 from "AE_Testing_RS_1" and Model_1 from "AE_Testing_RS_He" to be overlaid, where the loss and validation loss from "AE_Testing_RS_1/Model_1/Training_History.csv" are in dark red and light red respectively, and the loss and validation loss from "AE_Testing_RS_He/Model_1/Training_History.csv" are in dark blue and light blue respectively. I then want to do the same for Model_2 from "AE_Testing_RS_1" and Model_2 from "AE_Testing_RS_He" etc for models 1-9. Please write me some code to do this.

# %% [raw]
# For each model I now also want to print the median loss and validation loss values between epoch 0-199, 200-399, 400-599, 600-799, 800-999, 1000-1199, 1200-1399, 1400-1599, 1600-1799, 1800-1999. For example, for Model_1 from "AE_Testing_RS_1", I would want the median loss value between epochs 0-199, and the epoch at which the median loss is found, the median validation loss, and the epoch at which this is found. I then want to repeat this for epochs 200-399, 400-599, 600-799, 800-999, 1000-1199, 1200-1399, 1400-1599, 1600-1799 and 1800-1999.

# %% [raw]
# For each model I now also want to print the standard deviation of loss and validation loss values between epoch 0-199, 200-399, 400-599, 600-799, 800-999, 1000-1199, 1200-1399, 1400-1599, 1600-1799, 1800-1999. For example, for Model_1 from "AE_Testing_RS_1", I would want the standard deviation of the loss value between epochs 0-199, and the standard deviation for validation loss. I then want to repeat this for epochs 200-399, 400-599, 600-799, 800-999, 1000-1199, 1200-1399, 1400-1599, 1600-1799 and 1800-1999.

# %% [markdown]
# ## Training Time:
# - Model 1: 30s/epoch
# - Model 2: 52s/epoch
# - Model 3: 15.5s/epoch
# - Model 4: 33s/epoch
# - Model 5: 30s/epoch
# - Model 6: 8s/epoch
# - Model 7: 17s/epoch
# - Model 8: 12s/epoch
# - Model 9: s/epoch
